# %% [markdown]
# <a href="https://colab.research.google.com/github/kagglematsuo/Rapid_Challenge_Report/blob/master/predict_word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/DNN_code_colab_lesson_3_4/lesson_3/3_2_tf_languagemodel')

# %% [markdown]
# # predict_word

# %%
import tensorflow as tf
import numpy as np
import re
import glob
import collections
import random
import pickle
import time
import datetime
import os
# %tensorflow_version 1.x

# logging levelを変更
# tf.logging.set_verbosity(tf.logging.ERROR)

class Corpus:
    def __init__(self):
        self.unknown_word_symbol = "<???>" # 出現回数の少ない単語は未知語として定義しておく
        self.unknown_word_threshold = 3 # 未知語と定義する単語の出現回数の閾値
        self.corpus_file = "./corpus/**/*.txt"
        self.corpus_encoding = "utf-8"
        self.dictionary_filename = "./data_for_predict/word_dict.dic"
        self.chunk_size = 5
        self.load_dict()

        words = []
        for filename in glob.glob(self.corpus_file, recursive=True):
            with open(filename, "r", encoding=self.corpus_encoding) as f:

                # word breaking
                text = f.read()
                # 全ての文字を小文字に統一し、改行をスペースに変換
                text = text.lower().replace("\n", " ")
                # 特定の文字以外の文字を空文字に置換する
                text = re.sub(r"[^a-z '\-]", "", text)
                # 複数のスペースはスペース一文字に変換
                text = re.sub(r"[ ]+", " ", text)

                # 前処理： '-' で始まる単語は無視する
                words = [ word for word in text.split() if not word.startswith("-")]


        self.data_n = len(words) - self.chunk_size
        self.data = self.seq_to_matrix(words)

    def prepare_data(self):
        """
        訓練データとテストデータを準備する。
        data_n = ( text データの総単語数 ) - chunk_size
        input: (data_n, chunk_size, vocabulary_size)
        output: (data_n, vocabulary_size)
        """

        # 入力と出力の次元テンソルを準備
        all_input = np.zeros([self.chunk_size, self.vocabulary_size, self.data_n])
        all_output = np.zeros([self.vocabulary_size, self.data_n])

        # 準備したテンソルに、コーパスの one-hot 表現(self.data) のデータを埋めていく
        # i 番目から ( i + chunk_size - 1 ) 番目までの単語が１組の入力となる
        # このときの出力は ( i + chunk_size ) 番目の単語
        for i in range(self.data_n):
            all_output[:, i] = self.data[:, i + self.chunk_size] # (i + chunk_size) 番目の単語の one-hot ベクトル
            for j in range(self.chunk_size):
                all_input[j, :, i] = self.data[:, i + self.chunk_size - j - 1]

        # 後に使うデータ形式に合わせるために転置を取る
        all_input = all_input.transpose([2, 0, 1])
        all_output = all_output.transpose()

        # 訓練データ：テストデータを 4 : 1 に分割する
        training_num = ( self.data_n * 4 ) // 5
        return all_input[:training_num], all_output[:training_num], all_input[training_num:], all_output[training_num:]


    def build_dict(self):
        # コーパス全体を見て、単語の出現回数をカウントする
        counter = collections.Counter()
        for filename in glob.glob(self.corpus_file, recursive=True):
            with open(filename, "r", encoding=self.corpus_encoding) as f:

                # word breaking
                text = f.read()
                # 全ての文字を小文字に統一し、改行をスペースに変換
                text = text.lower().replace("\n", " ")
                # 特定の文字以外の文字を空文字に置換する
                text = re.sub(r"[^a-z '\-]", "", text)
                # 複数のスペースはスペース一文字に変換
                text = re.sub(r"[ ]+", " ", text)

                # 前処理： '-' で始まる単語は無視する
                words = [word for word in text.split() if not word.startswith("-")]

                counter.update(words)

        # 出現頻度の低い単語を一つの記号にまとめる
        word_id = 0
        dictionary = {}
        for word, count in counter.items():
            if count <= self.unknown_word_threshold:
                continue

            dictionary[word] = word_id
            word_id += 1
        dictionary[self.unknown_word_symbol] = word_id

        print("総単語数：", len(dictionary))

        # 辞書を pickle を使って保存しておく
        with open(self.dictionary_filename, "wb") as f:
            pickle.dump(dictionary, f)
            print("Dictionary is saved to", self.dictionary_filename)

        self.dictionary = dictionary

        print(self.dictionary)

    def load_dict(self):
        with open(self.dictionary_filename, "rb") as f:
            self.dictionary = pickle.load(f)
            self.vocabulary_size = len(self.dictionary)
            self.input_layer_size = len(self.dictionary)
            self.output_layer_size = len(self.dictionary)
            print("総単語数: ", self.input_layer_size)

    def get_word_id(self, word):
        # print(word)
        # print(self.dictionary)
        # print(self.unknown_word_symbol)
        # print(self.dictionary[self.unknown_word_symbol])
        # print(self.dictionary.get(word, self.dictionary[self.unknown_word_symbol]))
        return self.dictionary.get(word, self.dictionary[self.unknown_word_symbol])

    # 入力された単語を one-hot ベクトルにする
    def to_one_hot(self, word):
        index = self.get_word_id(word)
        data = np.zeros(self.vocabulary_size)
        data[index] = 1
        return data

    def seq_to_matrix(self, seq):
        print(seq)
        data = np.array([self.to_one_hot(word) for word in seq]) # (data_n, vocabulary_size)
        return data.transpose() # (vocabulary_size, data_n)

class Language:
    """
    input layer: self.vocabulary_size
    hidden layer: rnn_size = 30
    output layer: self.vocabulary_size
    """

    def __init__(self):
        self.corpus = Corpus()
        self.dictionary = self.corpus.dictionary
        self.vocabulary_size = len(self.dictionary) # 単語数
        self.input_layer_size = self.vocabulary_size # 入力層の数
        self.hidden_layer_size = 30 # 隠れ層の RNN ユニットの数
        self.output_layer_size = self.vocabulary_size # 出力層の数
        self.batch_size = 128 # バッチサイズ
        self.chunk_size = 5 # 展開するシーケンスの数。c_0, c_1, ..., c_(chunk_size - 1) を入力し、c_(chunk_size) 番目の単語の確率が出力される。
        self.learning_rate = 0.005 # 学習率
        self.epochs = 1000 # 学習するエポック数
        self.forget_bias = 1.0 # LSTM における忘却ゲートのバイアス
        self.model_filename = "./data_for_predict/predict_model.ckpt"
        self.unknown_word_symbol = self.corpus.unknown_word_symbol

    def inference(self, input_data, initial_state):
        """
        :param input_data: (batch_size, chunk_size, vocabulary_size) 次元のテンソル
        :param initial_state: (batch_size, hidden_layer_size) 次元の行列
        :return:
        """
        # 重みとバイアスの初期化
        hidden_w = tf.Variable(tf.truncated_normal([self.input_layer_size, self.hidden_layer_size], stddev=0.01))
        hidden_b = tf.Variable(tf.ones([self.hidden_layer_size]))
        output_w = tf.Variable(tf.truncated_normal([self.hidden_layer_size, self.output_layer_size], stddev=0.01))
        output_b = tf.Variable(tf.ones([self.output_layer_size]))

        # BasicLSTMCell, BasicRNNCell は (batch_size, hidden_layer_size) が chunk_size 数ぶんつながったリストを入力とする。
        # 現時点での入力データは (batch_size, chunk_size, input_layer_size) という３次元のテンソルなので
        # tf.transpose や tf.reshape などを駆使してテンソルのサイズを調整する。

        input_data = tf.transpose(input_data, [1, 0, 2]) # 転置。(chunk_size, batch_size, vocabulary_size)
        input_data = tf.reshape(input_data, [-1, self.input_layer_size]) # 変形。(chunk_size * batch_size, input_layer_size)
        input_data = tf.matmul(input_data, hidden_w) + hidden_b # 重みWとバイアスBを適用。 (chunk_size, batch_size, hidden_layer_size)
        input_data = tf.split(input_data, self.chunk_size, 0) # リストに分割。chunk_size * (batch_size, hidden_layer_size)

        # RNN のセルを定義する。RNN Cell の他に LSTM のセルや GRU のセルなどが利用できる。
        cell = tf.nn.rnn_cell.BasicRNNCell(self.hidden_layer_size)
        outputs, states = tf.nn.static_rnn(cell, input_data, initial_state=initial_state)
        
        # 最後に隠れ層から出力層につながる重みとバイアスを処理する
        # 最終的に softmax 関数で処理し、確率として解釈される。
        # softmax 関数はこの関数の外で定義する。
        output = tf.matmul(outputs[-1], output_w) + output_b

        return output

    def loss(self, logits, labels):
        cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))

        return cost

    def training(self, cost):
        # 今回は最適化手法として Adam を選択する。
        # ここの AdamOptimizer の部分を変えることで、Adagrad, Adadelta などの他の最適化手法を選択することができる
        optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate).minimize(cost)

        return optimizer

    def train(self):
        # 変数などの用意
        input_data = tf.placeholder("float", [None, self.chunk_size, self.input_layer_size])
        actual_labels = tf.placeholder("float", [None, self.output_layer_size])
        initial_state = tf.placeholder("float", [None, self.hidden_layer_size])

        prediction = self.inference(input_data, initial_state)
        cost = self.loss(prediction, actual_labels)
        optimizer = self.training(cost)
        correct = tf.equal(tf.argmax(prediction, 1), tf.argmax(actual_labels, 1))
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

        # TensorBoard で可視化するため、クロスエントロピーをサマリーに追加
        tf.summary.scalar("Cross entropy: ", cost)
        summary = tf.summary.merge_all()

        # 訓練・テストデータの用意
        # corpus = Corpus()
        trX, trY, teX, teY = self.corpus.prepare_data()
        training_num = trX.shape[0]

        # ログを保存するためのディレクトリ
        timestamp = time.time()
        dirname = datetime.datetime.fromtimestamp(timestamp).strftime("%Y%m%d%H%M%S")

        # ここから実際に学習を走らせる
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            summary_writer = tf.summary.FileWriter("./log/" + dirname, sess.graph)

            # エポックを回す
            for epoch in range(self.epochs):
                step = 0
                epoch_loss = 0
                epoch_acc = 0

                # 訓練データをバッチサイズごとに分けて学習させる (= optimizer を走らせる)
                # エポックごとの損失関数の合計値や（訓練データに対する）精度も計算しておく
                while (step + 1) * self.batch_size < training_num:
                    start_idx = step * self.batch_size
                    end_idx = (step + 1) * self.batch_size

                    batch_xs = trX[start_idx:end_idx, :, :]
                    batch_ys = trY[start_idx:end_idx, :]

                    _, c, a = sess.run([optimizer, cost, accuracy],
                                       feed_dict={input_data: batch_xs,
                                                  actual_labels: batch_ys,
                                                  initial_state: np.zeros([self.batch_size, self.hidden_layer_size])
                                                  }
                                       )
                    epoch_loss += c
                    epoch_acc += a
                    step += 1

                # コンソールに損失関数の値や精度を出力しておく
                print("Epoch", epoch, "completed ouf of", self.epochs, "-- loss:", epoch_loss, " -- accuracy:",
                      epoch_acc / step)

                # Epochが終わるごとにTensorBoard用に値を保存
                summary_str = sess.run(summary, feed_dict={input_data: trX,
                                                           actual_labels: trY,
                                                           initial_state: np.zeros(
                                                               [trX.shape[0],
                                                                self.hidden_layer_size]
                                                           )
                                                           }
                                       )
                summary_writer.add_summary(summary_str, epoch)
                summary_writer.flush()

            # 学習したモデルも保存しておく
            saver = tf.train.Saver()
            saver.save(sess, self.model_filename)

            # 最後にテストデータでの精度を計算して表示する
            a = sess.run(accuracy, feed_dict={input_data: teX, actual_labels: teY,
                                              initial_state: np.zeros([teX.shape[0], self.hidden_layer_size])})
            print("Accuracy on test:", a)


    def predict(self, seq):
        """
        文章を入力したときに次に来る単語を予測する
        :param seq: 予測したい単語の直前の文字列。chunk_size 以上の単語数が必要。
        :return:
        """

        # 最初に復元したい変数をすべて定義してしまいます
        # tf.reset_default_graph()
        tf.compat.v1.reset_default_graph()
        input_data = tf.placeholder("float", [None, self.chunk_size, self.input_layer_size])
        initial_state = tf.placeholder("float", [None, self.hidden_layer_size])
        prediction = tf.nn.softmax(self.inference(input_data, initial_state))
        predicted_labels = tf.argmax(prediction, 1)

        # 入力データの作成
        # seq を one-hot 表現に変換する。
        words = [word for word in seq.split() if not word.startswith("-")]
        x = np.zeros([1, self.chunk_size, self.input_layer_size])
        for i in range(self.chunk_size):
            word = seq[len(words) - self.chunk_size + i]
            index = self.dictionary.get(word, self.dictionary[self.unknown_word_symbol])
            x[0][i][index] = 1
        feed_dict = {
            input_data: x, # (1, chunk_size, vocabulary_size)
            initial_state: np.zeros([1, self.hidden_layer_size])
        }

        # tf.Session()を用意
        with tf.Session() as sess:
            # 保存したモデルをロードする。ロード前にすべての変数を用意しておく必要がある。
            saver = tf.train.Saver()
            saver.restore(sess, self.model_filename)

            # ロードしたモデルを使って予測結果を計算
            u, v = sess.run([prediction, predicted_labels], feed_dict=feed_dict)

            keys = list(self.dictionary.keys())


            # コンソールに文字ごとの確率を表示
            for i in range(self.vocabulary_size):
                c = self.unknown_word_symbol if i == (self.vocabulary_size - 1) else keys[i]
                print(c, ":", u[0][i])

            print("Prediction:", seq + " " + ("<???>" if v[0] == (self.vocabulary_size - 1) else keys[v[0]]))

        return u[0]


def build_dict():
    cp = Corpus()
    cp.build_dict()

if __name__ == "__main__":
    #build_dict()

    ln = Language()

    # 学習するときに呼び出す
    #ln.train()

    # 保存したモデルを使って単語の予測をする
    ln.predict("some of them looks like")
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# beating : 1.3192061e-14
# authentic : 1.490185e-14
# glow : 1.5293752e-14
# oy : 1.4680223e-14
# emotion : 1.4983705e-14
# delight : 1.40041744e-14
# nuclear : 1.4860014e-14
# dropped : 1.4963255e-14
# hiroshima : 1.3928387e-14
# beings : 1.5822535e-14
# tens : 1.5364802e-14
# burned : 1.3809692e-14
# homeless : 1.5643777e-14
# albert : 1.4478839e-14
# initiated : 1.32933994e-14
# bomb : 1.356966e-14
# theoretical : 1.4577154e-14
# radio : 1.4376196e-14
# traditionally : 1.35633726e-14
# oi : 1.5766443e-14
# souls : 1.4353648e-14
# assigned : 1.4012349e-14
# gallery : 1.5750481e-14
# easily : 1.553015e-14
# coins : 1.490367e-14
# timeless : 1.4624134e-14
# inevitably : 1.441194e-14
# trips : 1.664325e-14
# expressions : 1.518012e-14
# raw : 1.2960639e-14
# idioms : 1.2821083e-14
# magic : 1.4077016e-14
# handed : 1.3351614e-14
# blonde : 1.2911687e-14
# diamond : 1.4749829e-14
# charity : 1.5063595e-14
# ball : 1.5066383e-14
# lipschitz : 1.381504e-14
# stone : 1.3465729e-14
# sighed : 1.395977e-14
# feminist : 1.7686902e-14
# britain : 1.3061743e-14
# movement : 1.4768916e-14
# largely : 1.4008181e-14
# cruise : 1.3874163e-14
# missiles : 1.5027035e-14
# village : 1.4716837e-14
# elsewhere : 2.765201e-15
# ignorant : 1.4561201e-14
# jacket : 1.4211175e-14
# centre : 1.4279508e-14
# studies : 1.1551814e-11
# bear : 1.28956396e-14
# consists : 1.573553e-14
# rewriting : 1.536354e-14
# dawn : 1.6215158e-14
# demonstrating : 1.3151389e-14
# themes : 1.5186838e-14
# advancement : 1.6285208e-14
# agriculture : 1.4942466e-14
# despite : 1.4373043e-14
# stupidity : 1.4589865e-14
# domination : 1.606095e-14
# superiority : 1.571822e-14
# primitive : 1.3121371e-14
# religions : 1.4678039e-14
# egyptian : 1.39187994e-14
# rulers : 1.38962514e-14
# thesis : 1.4377512e-14
# counting : 1.4958748e-14
# track : 1.6071368e-14
# accepts : 1.4374166e-14
# speculation : 1.4989822e-14
# laborers : 1.4278094e-14
# greek : 1.3171169e-14
# historian : 1.4486572e-14
# labour : 1.35918075e-14
# blows : 1.4370493e-14
# modern : 1.41012e-14
# researcher : 1.2356755e-14
# commanded : 1.4580434e-14
# sum : 1.41882355e-14
# sixth : 2.496592e-20
# bc : 1.3925863e-14
# pan : 1.3654428e-14
# flourished : 1.3517711e-14
# welfare : 1.4174927e-14
# roman : 1.5056185e-14
# nurse : 1.4860155e-14
# fourth : 1.4023953e-14
# cultures : 1.3483258e-14
# instrument : 1.4368521e-14
# blood : 1.6514175e-10
# bones : 1.5962061e-14
# preferred : 1.4236323e-14
# wild : 1.2597441e-14
# destiny : 1.549441e-14
# paul : 1.3648284e-14
# seller : 1.3574397e-14
# purple : 1.38539625e-14
# ibid : 1.6552865e-14
# array : 1.5294306e-14
# brilliant : 1.3050761e-14
# unusual : 1.3509334e-14
# inspiring : 1.4097839e-14
# preceding : 1.3943565e-14
# taste : 1.4553207e-14
# stroke : 1.5297749e-14
# grim : 1.6048149e-14
# clothing : 1.4420604e-14
# campbell : 1.3259973e-14
# analyses : 5.2381086e-08
# emerging : 1.5700272e-14
# islamic : 1.5424348e-14
# connected : 1.4090608e-14
# virgin : 1.311179e-14
# ancient : 1.6127438e-14
# treatment : 8.3587615e-16
# notably : 1.532295e-14
# etc : 1.4732143e-14
# unlikely : 1.4600054e-14
# ignored : 1.5555999e-14
# gods : 1.430748e-14
# identity : 1.4529215e-14
# meaningful : 1.4677143e-14
# roots : 1.2780261e-14
# wildly : 1.37389405e-14
# disease : 1.1581956e-14
# investigate : 1.3616458e-14
# cure : 1.4511573e-14
# blasts : 1.4174899e-14
# symptoms : 1.2739811e-14
# characterized : 3.2966708e-16
# concludes : 1.42108225e-14
# engage : 1.5028984e-14
# laurence : 1.3182856e-14
# urdang : 1.4539832e-14
# archaeology : 1.4420961e-14
# fragile : 1.4087893e-14
# turns : 1.557916e-14
# earliest : 1.5504992e-14
# stages : 1.524183e-14
# destroyed : 1.4299514e-14
# countless : 1.3952077e-14
# generations : 1.3425314e-14
# erosion : 1.2757708e-14
# prehistoric : 1.387218e-14
# developers : 1.4215756e-14
# fashionable : 1.5361402e-14
# discover : 1.3942022e-14
# greeks : 1.4001716e-14
# romans : 1.4492432e-14
# indians : 1.3721002e-14
# ruins : 1.4019728e-14
# followed : 8.1330315e-13
# troy : 1.5077163e-14
# artifacts : 1.4787518e-14
# dating : 1.3462956e-14
# pursuit : 1.2682352e-14
# museums : 1.3607396e-14
# classical : 1.5186838e-14
# documented : 1.5514545e-14
# tablets : 1.4237192e-14
# barely : 1.3549875e-14
# identify : 1.3935642e-14
# conclusions : 2.9813533e-15
# deep : 1.2981125e-14
# countryside : 1.4284277e-14
# precious : 1.4119609e-14
# clever : 1.400591e-14
# linguists : 1.4611391e-14
# germany : 1.28040245e-14
# ancestors : 1.3964831e-14
# jean : 1.4194135e-14
# myriad : 1.3865249e-14
# revealed : 1.5216005e-14
# crete : 1.476182e-14
# indo-european : 1.3000401e-14
# linguistic : 1.3608098e-14
# undoubtedly : 1.4672887e-14
# vanished : 1.4893894e-14
# unimportant : 1.5161456e-14
# establish : 1.2562122e-14
# dialect : 1.3347337e-14
# examining : 3.032881e-15
# swedish : 1.4965768e-14
# dutch : 1.314557e-14
# spanish : 1.2700362e-14
# portuguese : 1.4012135e-14
# remote : 1.41281225e-14
# varieties : 1.4087732e-14
# resort : 1.4761059e-14
# fingers : 1.5386972e-14
# toes : 1.5219026e-14
# shifts : 1.581964e-14
# nearby : 1.4071888e-14
# hence : 1.4019246e-14
# classified : 2.0794998e-14
# finnish : 1.5051132e-14
# computers : 1.4321132e-14
# emerged : 1.465619e-14
# linked : 1.4465258e-14
# showing : 1.5335874e-14
# constantly : 1.4577988e-14
# accuracy : 1.4787915e-14
# trees : 1.520794e-14
# classification : 1.3247713e-14
# grammar : 1.3984661e-14
# resemble : 1.4824288e-14
# suitable : 1.4846358e-14
# soft : 1.3807163e-14
# organize : 1.3420192e-14
# alongside : 1.4088834e-14
# correlated : 1.4005295e-14
# digging : 1.2600661e-14
# disappeared : 1.2701082e-15
# sites : 1.346686e-14
# dim : 1.4110724e-14
# tearing : 1.31697115e-14
# erected : 1.3893362e-14
# archaeological : 1.4807276e-14
# examines : 1.3327164e-14
# significance : 1.334044e-14
# interfere : 1.440235e-14
# finds : 1.5591083e-14
# importance : 1.4196951e-14
# yield : 5.010421e-14
# notwithstanding : 1.6167169e-14
# investigations : 1.4933604e-14
# insight : 1.3674706e-14
# sprang : 1.479491e-14
# descended : 1.27540106e-14
# nonetheless : 1.5100302e-14
# renfrew : 1.5469663e-14
# eastward : 1.5501296e-14
# influences : 1.36697e-14
# recognizable : 1.4326077e-14
# manifestations : 1.4495417e-14
# assess : 1.5238458e-14
# validity : 1.374033e-14
# contention : 1.4366026e-14
# separated : 1.4133432e-14
# iran : 1.4755822e-14
# pakistan : 1.365021e-14
# eastern : 1.4120984e-14
# indigenous : 1.3951172e-14
# pottery : 1.3295808e-14
# interpreted : 1.4830847e-14
# elite : 1.488089e-14
# presentation : 1.5503454e-14
# territory : 1.32751815e-14
# convincing : 1.4581047e-14
# overly : 1.3877605e-14
# boots : 1.306897e-14
# installation : 1.4992568e-14
# synonym : 1.4444524e-14
# manual : 1.5174473e-14
# descriptive : 2.1614159e-16
# spelt : 1.3215509e-14
# paragraph : 1.6693388e-14
# arrangement : 1.3244857e-14
# senses : 1.37766495e-14
# synonyms : 1.5545264e-14
# highlight : 1.4159416e-14
# desired : 1.4285693e-14
# highlighted : 1.4129066e-14
# involves : 1.327865e-14
# mathematics : 1.5528106e-14
# round : 1.5375237e-14
# alternatives : 1.4950248e-14
# jumped : 1.5207128e-14
# variants : 1.4942949e-14
# leapt : 1.4591284e-14
# preference : 1.456798e-14
# supplies : 1.368034e-14
# quantity : 1.4540027e-14
# reality : 1.3971358e-14
# allen : 1.5338184e-14
# walker : 1.3322716e-14
# scholarly : 1.3756639e-14
# informal : 1.41757376e-14
# crop : 1.4228939e-14
# station : 1.3972131e-14
# stations : 1.4307044e-14
# harold : 1.5343187e-14
# pilgrims : 1.4357507e-14
# bells : 1.39542605e-14
# ring : 1.464035e-14
# allowance : 1.369739e-14
# flag : 1.4928307e-14
# leaning : 1.5744443e-14
# invisible : 1.4881398e-14
# ensuring : 1.6024076e-14
# ample : 1.32145254e-14
# guests : 1.390593e-14
# greene : 1.4436069e-14
# jack : 1.4587444e-14
# genre : 1.2613887e-14
# occasional : 1.4824174e-14
# hidden : 1.448942e-14
# entry : 1.4838233e-14
# suffer : 1.4267313e-14
# affecting : 1.31284305e-14
# responds : 1.4613819e-14
# co : 1.3925465e-14
# jr : 1.3156682e-14
# associate : 1.4399247e-14
# warfare : 1.3687441e-14
# characteristic : 1.2854237e-14
# soldier : 1.3611862e-14
# rank : 1.427989e-14
# thus : 1.881344e-13
# corresponding : 1.4217357e-14
# demands : 1.5007159e-14
# goods : 1.5246044e-14
# whiskey : 1.5030534e-14
# readily : 1.4224651e-14
# acquaintance : 1.5252444e-14
# tackle : 1.4771563e-14
# tongue : 1.4423765e-14
# observations : 1.5029817e-14
# pet : 1.5658642e-14
# gathering : 1.4237707e-14
# unknown : 1.4085662e-14
# disclaimer : 1.4702415e-14
# load : 1.3279715e-14
# brass : 1.4309637e-14
# monkey : 1.536779e-14
# ship : 1.5013056e-14
# employed : 1.318537e-14
# fetch : 1.5836999e-14
# wooden : 1.39947216e-14
# metal : 1.5577973e-14
# pyramid : 1.50667e-14
# cannon : 1.2938311e-14
# iron : 1.508706e-14
# heavy : 1.5619625e-14
# freeze : 1.426043e-14
# household : 1.5057649e-14
# ornaments : 1.5045792e-14
# centuries : 1.3794476e-14
# imported : 1.5311703e-14
# grace : 1.4768379e-14
# edwardian : 1.4627676e-14
# shops : 1.6565373e-14
# ears : 1.3367464e-14
# eg : 1.3121321e-14
# fu : 1.2982412e-14
# representing : 1.4591452e-14
# clusters : 1.4397929e-14
# produces : 1.4441165e-14
# coffee : 1.5019299e-14
# expresses : 1.3559544e-14
# frantic : 1.4242081e-14
# scrap : 1.382221e-14
# safire : 1.4940699e-14
# writes : 1.4781823e-14
# column : 3.5721426e-11
# magazine : 1.5924052e-14
# editorial : 1.4472737e-14
# style : 1.4199225e-14
# reflected : 1.4494863e-14
# columns : 1.2845709e-14
# n : 6.154182e-11
# y : 1.5138859e-14
# cute : 1.3752495e-14
# uttered : 1.4462058e-14
# andrew : 1.3628409e-14
# norman : 1.3754122e-14
# arch : 1.5642164e-14
# knee : 1.4114978e-14
# pronounced : 1.3317381e-14
# appeal : 1.31358945e-14
# containing : 6.20779e-14
# deliberately : 1.25723576e-14
# collections : 1.2769296e-14
# prints : 1.330758e-14
# inclusion : 1.4435986e-14
# interaction : 1.3460618e-14
# accused : 1.3740067e-14
# influential : 1.4564842e-14
# libraries : 1.5370663e-14
# mc : 1.3559286e-14
# m : 1.448127e-14
# meaningless : 1.6277474e-14
# conventional : 1.4623353e-14
# physics : 1.5104276e-14
# stab : 1.3393649e-14
# heading : 1.4686637e-14
# ate : 1.4439098e-14
# futile : 1.3943006e-14
# rely : 1.3279739e-14
# seeking : 1.3883642e-14
# loose : 1.4485854e-14
# lacking : 1.619093e-14
# lo : 1.3906726e-14
# exclamation : 1.4163522e-14
# utility : 1.4951102e-14
# fantasy : 1.3746987e-14
# bull : 1.4930045e-14
# johns : 1.4295751e-14
# faults : 1.39349236e-14
# accompanying : 1.42082204e-14
# abroad : 1.5346994e-14
# battle : 1.3881682e-14
# purity : 1.3701258e-14
# condemned : 1.38710946e-14
# newly : 1.5114422e-14
# academy : 1.4355098e-14
# museum : 1.5592242e-14
# boycott : 1.49622e-14
# regrets : 1.5237382e-14
# supplement : 1.2841592e-14
# harsh : 1.4401032e-14
# participating : 1.40189255e-14
# arises : 1.4832404e-14
# carriage : 1.4312394e-14
# fred : 1.392488e-14
# approaching : 1.445748e-14
# obstacle : 1.3052677e-14
# cross-country : 1.37458345e-14
# grand : 4.3388883e-14
# eliminated : 1.4181741e-14
# cannons : 1.4380419e-14
# marvelous : 1.3592403e-14
# rationale : 1.3129583e-14
# observation : 1.3750764e-14
# increasingly : 1.5275443e-14
# widespread : 1.4446288e-14
# familiarity : 1.3849946e-14
# mythology : 1.3075403e-14
# unable : 1.3401392e-14
# oats : 1.456587e-14
# expression : 1.4859958e-14
# event : 1.2903685e-14
# dull : 1.5393606e-14
# square : 7.181453e-10
# spill : 1.33738405e-14
# calculated : 2.7424112e-11
# pi : 1.3175214e-14
# borrowed : 1.6946634e-14
# animal : 1.36631564e-14
# suggestions : 1.3709518e-14
# nonsense : 1.5974731e-14
# maps : 1.5928456e-14
# geography : 1.6357866e-14
# branch : 1.40978664e-14
# dialects : 1.4856499e-14
# prominent : 1.5001004e-14
# practitioners : 1.4588669e-14
# wright : 1.4697985e-14
# proceeded : 1.3878823e-14
# conducted : 1.4246972e-14
# survey : 1.5845518e-14
# studied : 1.7270158e-15
# extracted : 1.4420905e-14
# aided : 1.3380524e-14
# delicious : 1.4535785e-14
# selected : 1.4562758e-14
# boundary : 1.2842596e-14
# coast : 1.34057635e-14
# institutions : 1.5086282e-14
# indulge : 1.5290136e-14
# connect : 1.3899751e-14
# employ : 1.4010265e-14
# iso : 1.4691819e-14
# oceans : 1.37836935e-14
# undertaken : 1.4071646e-14
# strict : 1.559367e-14
# maintenance : 1.4353949e-14
# boundaries : 1.6548037e-14
# periodicals : 1.3909564e-14
# television : 1.6065759e-14
# establishment : 1.5162815e-14
# prestige : 1.31406565e-14
# slower : 1.4412491e-14
# speeding : 1.5374005e-14
# literary : 1.4944888e-14
# varying : 1.4044618e-14
# colleges : 1.4154232e-14
# universities : 1.36081755e-14
# profession : 1.4631305e-14
# apparent : 1.5066526e-14
# oxford : 1.4100797e-14
# series : 1.4629182e-14
# photographs : 1.3660264e-14
# samuel : 1.4317254e-14
# devil : 1.4742375e-14
# railroad : 1.5355367e-14
# creations : 1.4653367e-14
# colorful : 1.366201e-14
# suicide : 1.5647805e-14
# reveals : 1.5781937e-14
# recommend : 1.3093821e-14
# specialized : 1.3958626e-14
# faculty : 1.40653124e-14
# protest : 1.3418349e-14
# cornell : 1.3484955e-14
# opera : 1.4384754e-14
# stereo : 1.3266651e-14
# re : 1.4646773e-14
# stretch : 1.5220157e-14
# frontier : 1.4524311e-14
# th-century : 1.2681723e-14
# harlem : 1.519756e-14
# consisted : 1.4688597e-14
# beckett : 1.5361166e-14
# webb : 1.4832348e-14
# rape : 1.4345873e-14
# chatterbox : 1.5464114e-14
# broaddrick's : 1.3004122e-14
# assessing : 1.41911316e-14
# intellectual : 1.4433343e-14
# indis : 1.3535359e-14
# publications : 1.4705444e-14
# posting : 1.41886675e-14
# receiving : 1.5044472e-14
# broaddrick : 1.4503244e-14
# gov : 1.3848625e-14
# pardon : 1.3734932e-14
# failing : 1.3679819e-14
# rabinowitz : 1.4367862e-14
# feb : 1.3702826e-14
# omission : 1.522823e-14
# scores : 1.4416065e-14
# latest : 1.4981275e-14
# awarding : 1.566868e-14
# bonus : 1.7052532e-14
# besides : 1.4261382e-14
# unethical : 1.498322e-14
# bureau : 1.3831597e-14
# murray : 1.2958291e-14
# feeding : 1.2956734e-14
# replied : 1.3602259e-14
# instructed : 1.628788e-14
# causes : 1.3351844e-14
# embarrassment : 1.4976105e-14
# kisses : 1.357261e-14
# trip : 1.4273791e-14
# usa : 1.28767634e-14
# nyt : 1.4574178e-14
# publicly : 1.4085019e-14
# attempts : 1.4214807e-14
# troubles : 1.3011688e-14
# falling : 1.2057349e-14
# focuses : 1.5133055e-14
# striking : 1.483713e-14
# indicator : 1.4018659e-14
# mood : 1.3776386e-14
# minister : 1.4271014e-14
# retention : 1.2706419e-14
# waves : 1.4541525e-14
# survivors : 1.6237132e-14
# listings : 1.4596184e-14
# annual : 1.2836767e-14
# compensation : 1.5193559e-14
# rising : 1.4330205e-14
# diana : 1.3773601e-14
# grief : 1.4304833e-14
# goodwill : 1.2967167e-14
# ambassador : 1.3408091e-14
# shortly : 1.32550416e-14
# le : 1.2465457e-14
# criticism : 1.5297866e-14
# worldwide : 1.4674568e-14
# collapsing : 1.4289263e-14
# city's : 1.5909235e-14
# christopher : 1.5344534e-14
# hmmm : 1.4764972e-14
# desk : 1.4475e-14
# headline : 1.4438574e-14
# williams : 1.5696857e-14
# celebrating : 1.4859162e-14
# collect : 1.3850659e-14
# tales : 1.5807424e-14
# gates : 1.3300171e-14
# painted : 1.4906513e-14
# pin : 1.4982819e-14
# microsoft : 1.40760486e-14
# conscious : 1.4910153e-14
# executives : 1.5924597e-14
# informative : 1.4279646e-14
# lunch : 1.5796814e-14
# benefited : 1.445373e-14
# virginia : 1.5492161e-14
# silicon : 1.4913394e-14
# exciting : 1.4962058e-14
# contractors : 1.5780763e-14
# digital : 1.3594193e-14
# att : 1.4476684e-14
# encourages : 1.5370194e-14
# interconnection : 1.434497e-14
# dominate : 1.3808877e-14
# babylon : 1.3879194e-14
# empire : 1.4643421e-14
# dominated : 1.4639679e-14
# grip : 1.3872789e-14
# cheers : 1.2873572e-14
# fetal : 1.4404796e-14
# viability : 1.4126344e-14
# fetuses : 1.3580406e-14
# settle : 1.474364e-14
# quarter : 1.4939872e-14
# fetus : 1.41855284e-14
# moral : 1.4464016e-14
# ruled : 1.4364959e-14
# prolonged : 1.3378355e-14
# pregnancy : 1.4104887e-14
# determined : 1.42684e-14
# collision : 1.5221927e-14
# regulate : 1.4645152e-14
# rd : 1.3413847e-14
# successfully : 1.4713188e-14
# weigh : 1.4207489e-14
# lungs : 1.2827589e-14
# survival : 5.5841844e-07
# oxygen : 1.4614905e-14
# increases : 1.4715099e-14
# breathe : 1.4236323e-14
# damage : 1.5982656e-14
# substantially : 1.3887216e-14
# premature : 1.5485367e-14
# vary : 1.4413534e-14
# rural : 1.24032e-14
# units : 1.441524e-14
# fetus's : 1.5471579e-14
# attempting : 1.5751172e-14
# functioning : 1.4262796e-14
# eyelids : 1.3980634e-14
# onset : 1.4611811e-14
# respiratory : 1.3874429e-14
# constant : 1.5567102e-14
# findings : 8.62765e-07
# nationwide : 1.4669979e-14
# delivery : 1.40593595e-14
# crushed : 1.5539097e-14
# brains : 1.608302e-14
# regulation : 1.4939986e-14
# polls : 1.570761e-14
# performed : 1.1292954e-08
# palestinian : 1.4931666e-14
# dealer : 1.4668468e-14
# sale : 1.2776458e-14
# struggle : 1.4666259e-14
# biblical : 1.5993786e-14
# palestine : 1.4047324e-14
# ottoman : 1.4251428e-14
# jerusalem : 1.4742402e-14
# immigrants : 1.36194716e-14
# tracts : 1.2417475e-14
# physically : 1.31678785e-14
# arabs : 1.4517941e-14
# laying : 1.5018784e-14
# charter : 1.5603189e-14
# mandate : 1.479457e-14
# guidelines : 1.0627369e-14
# peasants : 1.3644275e-14
# displaced : 1.3828775e-14
# threat : 1.4204725e-14
# displacement : 1.465538e-14
# railed : 1.542176e-14
# acquisition : 1.5713572e-14
# conspiracy : 1.4052361e-14
# muslims : 1.3511859e-14
# anxious : 1.4699723e-14
# imposing : 1.4214807e-14
# crowded : 1.5306563e-14
# buyers : 1.532295e-14
# ineffective : 1.3594763e-14
# spiritual : 1.4950533e-14
# guerrilla : 1.3430179e-14
# drew : 2.828539e-13
# farms : 1.3230415e-14
# competing : 1.5825281e-14
# successes : 1.450471e-14
# sovereignty : 1.45395e-14
# independence : 1.3758267e-14
# refugees : 1.403471e-14
# fled : 1.4768324e-14
# zones : 1.453473e-14
# retained : 1.38491005e-14
# compares : 1.5553092e-14
# executed : 1.4945229e-14
# reflects : 1.4543161e-14
# substantial : 2.6930024e-11
# stephanopoulos : 1.4890173e-14
# aide : 1.3656096e-14
# popped : 1.5197821e-14
# demonstrate : 1.4910038e-14
# disgusting : 1.3909564e-14
# eager : 1.4002197e-14
# clinton's : 1.531512e-14
# lies : 1.3638239e-14
# fool : 1.3237457e-14
# namely : 1.5231745e-14
# disturbing : 1.4004495e-14
# documentary : 1.414457e-14
# interviews : 1.5138656e-14
# defenders : 1.3026662e-14
# maureen : 1.4485136e-14
# corps : 1.3966615e-14
# analyst : 1.3467373e-14
# sen : 1.5193039e-14
# celebrity : 1.3567461e-14
# minimal : 1.442825e-14
# motions : 1.499148e-14
# paula : 1.438297e-14
# tobacco : 1.4744878e-14
# rare : 1.3590977e-14
# outlying : 1.4392657e-14
# poll : 1.6829676e-14
# concerning : 1.460529e-14
# mississippi : 1.4141953e-14
# suits : 1.4366848e-14
# fees : 1.37200084e-14
# notable : 1.4191347e-14
# acute : 1.5509812e-14
# wsj : 1.3812696e-14
# steeper : 1.4430206e-14
# cable : 1.6109576e-14
# espn : 1.383086e-14
# habit : 1.4915017e-14
# programming : 1.4323263e-14
# scan : 1.427597e-14
# foods : 1.391158e-14
# gifts : 1.5841349e-14
# reset : 1.25195925e-14
# knees : 1.33153495e-14
# airline : 1.4612841e-14
# travelers : 1.6232489e-14
# jet : 1.5033717e-14
# lag : 1.5070839e-14
# stepping : 1.3008066e-14
# picks : 1.35903285e-14
# lengthy : 1.4886963e-14
# curls : 1.48101e-14
# heights : 1.4462967e-14
# subtle : 1.3838459e-14
# inspired : 1.4908957e-14
# embraced : 1.4618752e-14
# markers : 1.3920021e-14
# artist : 1.4090177e-14
# essentials : 1.3510159e-14
# steven : 1.5814962e-14
# hair : 1.4269219e-14
# placement : 1.4157445e-14
# pr : 1.4376963e-14
# seeds : 1.6017842e-14
# hillary : 1.3945506e-14
# giuliani : 1.4238224e-14
# symbolic : 1.5540342e-14
# fortunes : 1.5207592e-14
# marital : 1.3245134e-14
# risky : 1.4402489e-14
# qualities : 1.4178604e-14
# donna : 1.3889045e-14
# hanover : 1.560307e-14
# dynamic : 1.556633e-14
# amazing : 1.4412025e-14
# motives : 1.3219895e-14
# lip : 1.4546156e-14
# father's : 1.5168427e-14
# killer : 1.4428774e-14
# savin : 1.3136397e-14
# corp : 1.6285642e-14
# third-quarter : 1.505693e-14
# year-earlier : 1.5909325e-14
# cent : 1.30703155e-14
# spokesman : 1.4500616e-14
# operations : 1.391588e-14
# offset : 1.6794217e-13
# investments : 1.4817786e-14
# ventures : 1.4472598e-14
# revenue : 1.4937506e-14
# declined : 1.4351704e-14
# segments : 1.4590617e-14
# completed : 1.3537449e-14
# tender : 1.3677263e-14
# inc : 1.5597893e-14
# shareholders : 1.518962e-14
# shares : 1.3962194e-14
# outstanding : 1.468151e-14
# deadline : 1.3288379e-14
# formally : 1.529807e-14
# studio : 1.420031e-14
# month : 1.35096436e-14
# producers : 1.3594555e-14
# jon : 1.463856e-14
# warner : 1.5183333e-14
# dispute : 1.36617495e-14
# expects : 1.437839e-14
# overhead : 1.3958891e-14
# functions : 1.4642974e-14
# quarters : 1.3390942e-14
# comparison : 1.32939305e-14
# earnings : 1.38486516e-14
# gains : 1.5676693e-14
# hurricane : 1.4905317e-14
# payments : 1.5490803e-14
# pricing : 1.5310505e-14
# ralston : 1.4290735e-14
# fourth-quarter : 1.4969422e-14
# restructuring : 1.5424819e-14
# year's : 1.435729e-14
# sept : 1.4057e-14
# seafood : 1.4259232e-14
# facility : 1.4730486e-14
# cake : 1.4869313e-14
# reduction : 1.483611e-14
# attributed : 1.5093966e-14
# ingredients : 1.2725822e-14
# pressures : 1.4104644e-14
# advertising : 1.4588445e-14
# volume : 1.5694045e-14
# operating : 1.299698e-14
# continental : 1.4696191e-14
# bread : 1.532564e-14
# unit : 1.6787771e-14
# south : 1.4303088e-14
# composite : 1.3865011e-14
# trading : 1.4657839e-14
# pacific : 1.479175e-14
# royal : 1.429695e-14
# toronto : 1.425393e-14
# thrift : 1.3809008e-14
# obtain : 1.3650732e-14
# regulatory : 1.3661958e-14
# transaction : 1.5917735e-14
# nj : 1.4323153e-14
# financing : 1.4155716e-14
# requirements : 1.4132623e-14
# plastic : 1.5249185e-14
# displays : 1.4613873e-14
# toy : 1.410841e-14
# maker : 1.5332597e-14
# owed : 1.573988e-14
# ranger : 1.3345097e-14
# company's : 1.4763732e-14
# adam : 1.398058e-14
# plunged : 1.3037624e-14
# patch : 1.3571342e-14
# bankruptcy : 1.3985248e-14
# reuters : 1.4006551e-14
# plc : 1.3849311e-14
# reupke : 1.4530323e-14
# resigned : 1.389938e-14
# separation : 1.3717967e-14
# appointment : 1.5564073e-14
# responsibilities : 1.2804953e-14
# duties : 1.3323022e-14
# departure : 1.5404121e-14
# profits : 1.537946e-14
# pence : 1.5278968e-14
# over-the-counter : 1.5028211e-14
# unchanged : 1.35450944e-14
# judah : 1.4995256e-14
# deputy : 1.2762283e-14
# technical : 1.2904989e-14
# van : 1.4210064e-14
# calif : 1.2855414e-14
# mobile : 1.447304e-14
# one-time : 1.4842508e-14
# eliminate : 1.4702303e-14
# losses : 1.4828416e-14
# examined : 3.9792073e-20
# regulators : 1.4672442e-14
# midwest : 1.5346084e-14
# announced : 1.4761396e-14
# managers : 1.5349216e-14
# cxf : 1.4524643e-14
# francisco : 1.3225595e-14
# chronicle : 1.2429393e-14
# editors : 1.2329751e-14
# fruits : 1.4141765e-14
# vegetables : 1.5124918e-14
# herbs : 1.4880661e-14
# bitter : 1.5169987e-14
# melon : 1.4002331e-14
# indian : 1.3394568e-14
# skin : 1.4346558e-14
# climbing : 1.533175e-14
# asia : 1.6262919e-14
# americas : 1.415434e-14
# warm : 1.3178381e-14
# california's : 1.513092e-14
# asian : 1.5407646e-14
# specialty : 1.4450834e-14
# orange : 1.5198197e-14
# fresh : 1.402152e-14
# prominently : 1.4234885e-14
# flesh : 1.5529616e-14
# dry : 1.3978075e-14
# pork : 1.4236784e-14
# vietnam : 1.4224651e-14
# stuffed : 1.6262269e-14
# meat : 1.4306117e-14
# lightly : 1.4322826e-14
# mixture : 1.5287335e-14
# rice : 1.456373e-14
# nyt--- : 1.5193211e-14
# edt : 1.4608577e-14
# rep : 1.5051877e-14
# korea : 1.3758347e-14
# stemming : 1.4705473e-14
# recover : 1.5006815e-14
# devastation : 1.4362053e-14
# infrastructure : 1.4185664e-14
# richardson : 1.4192511e-14
# cox : 1.407492e-14
# heritage : 1.32338725e-14
# swap : 1.40897485e-14
# completion : 1.5887069e-14
# dividend : 1.5217574e-14
# customized : 1.4227394e-14
# operates : 1.4549847e-14
# karen : 1.3821076e-14
# ala : 1.5214468e-14
# vanderbilt : 1.31295325e-14
# bobby : 1.300871e-14
# sec : 1.3859406e-14
# gray : 1.2629993e-14
# tour : 1.3760287e-14
# martin : 1.4743191e-14
# reaches : 1.4329602e-14
# opens : 1.4863472e-14
# tech : 1.332968e-14
# beat : 1.3526842e-14
# t-shirts : 1.4277711e-14
# crimson : 1.3575174e-14
# mirror : 1.443238e-14
# coach : 1.6036797e-14
# cutcliffe : 1.4736218e-14
# peyton : 1.383136e-14
# rhythm : 1.3632751e-14
# clone : 1.5143826e-14
# pounds : 4.0270283e-08
# rex : 1.5309162e-14
# trophy : 1.2551345e-14
# promotional : 1.5533942e-14
# embarrassing : 1.4734756e-14
# calendar : 1.4687506e-14
# miami : 1.514605e-14
# ron : 1.35771165e-14
# exasperation : 1.33946716e-14
# excited : 1.4724866e-14
# atlanta : 1.4595182e-14
# nov : 1.33500355e-14
# dunkin' : 1.5144288e-14
# poison : 1.4914675e-14
# pill : 1.404987e-14
# launched : 1.3874534e-14
# delaware : 1.3536494e-14
# bidders : 1.5644761e-14
# receipt : 1.3288151e-14
# bids : 1.5118803e-14
# julia : 1.40145955e-14
# legend : 1.4170008e-14
# laugh : 1.4315834e-14
# culinary : 1.476182e-14
# chef : 1.37836935e-14
# cooks : 1.4638703e-14
# decade : 1.36840985e-14
# birthday : 1.6668985e-14
# dinners : 1.3866995e-14
# professionals : 1.5705663e-14
# moves : 1.4539556e-14
# aug : 1.5080729e-14
# rolled : 1.37879515e-14
# capabilities : 1.428959e-14
# pasadena : 1.4640043e-14
# progressive : 1.5718819e-14
# assisted : 1.3623888e-14
# arrangements : 1.3413591e-14
# legs : 1.4423326e-14
# ship's : 1.4312285e-14
# cambridge : 1.3372003e-14
# childs : 1.3837483e-14
# sorts : 1.4819172e-14
# walls : 1.3485238e-14
# recalls : 1.5222742e-14
# preserving : 1.3506139e-14
# awesome : 1.2640404e-14
# memories : 1.5256226e-14
# professional : 1.431862e-14
# boat : 1.562344e-14
# lit : 1.472484e-14
# collaboration : 1.4026388e-14
# revolution : 1.34566405e-14
# chefs : 1.4726384e-14
# celebrate : 1.509296e-14
# laurent : 1.4151559e-14
# counterpart : 1.4704492e-14
# siegel : 1.4526195e-14
# heads : 1.5040112e-14
# meal : 1.3688694e-14
# chocolate : 1.3812774e-14
# dessert : 1.3373023e-14
# menu : 1.5972629e-14
# composed : 1.5679203e-14
# atlantic : 1.3733779e-14
# sonoma : 1.2418942e-14
# breast : 1.4528743e-14
# la : 1.4525114e-14
# trends : 1.3966536e-14
# subscribed : 1.5389084e-14
# cuisine : 1.5020102e-14
# organic : 1.36723594e-14
# fitness : 1.37257666e-14
# modest : 1.2958019e-14
# kim : 1.40566236e-14
# alice : 1.5245173e-14
# turkey : 1.3039837e-14
# denise : 1.5059917e-14
# fascinating : 1.5657867e-14
# harry : 1.4950362e-14
# nightclub : 1.4618195e-14
# honesty : 1.5895403e-14
# bleeding : 1.2463364e-14
# syndicate : 1.5364009e-14
# fax : 1.5053026e-14
# optional : 1.3988957e-14
# trim : 1.5108828e-14
# michelle : 1.3115216e-14
# cole : 1.2371045e-14
# retailers : 1.5022278e-14
# resource : 1.4623995e-14
# fisheries : 1.463136e-14
# species : 1.3906381e-14
# extinction : 1.3635404e-14
# marine : 1.4679159e-14
# ecosystem : 1.3673663e-14
# consumer : 1.5196632e-14
# chilean : 1.2756735e-14
# seabass : 1.3905214e-14
# portland : 1.5782568e-14
# restaurants : 1.4562814e-14
# fish : 1.30543956e-14
# pirate : 1.6370382e-14
# popularity : 1.4566536e-14
# customers : 1.3915667e-14
# endangered : 1.4357452e-14
# slowly : 1.3993066e-14
# susan : 1.3597927e-14
# estimates : 1.5325872e-14
# tons : 1.4733127e-14
# ocean : 1.3525397e-14
# officially : 1.5156569e-14
# lobster : 1.4108438e-14
# discontinued : 1.41879645e-14
# buyer : 1.401299e-14
# shark : 1.4774269e-14
# formal : 1.3407758e-14
# institute : 1.5015996e-19
# catches : 1.3360328e-14
# depleted : 1.5471404e-14
# thrilled : 1.3585483e-14
# cycles : 1.3065455e-14
# sacrifice : 1.5019471e-14
# coastal : 1.23621765e-14
# packard : 1.476807e-14
# projects : 1.4456404e-14
# overfishing : 1.5880616e-14
# raising : 1.5181017e-14
# awareness : 1.6431634e-14
# web : 1.615484e-14
# habitat : 1.3341814e-14
# aquarium : 1.3619289e-14
# wallet : 1.4396995e-14
# guides : 1.4677367e-14
# jennifer : 1.4497353e-14
# arrive : 1.4814987e-14
# norm : 1.3292739e-14
# manhattan : 1.4384232e-14
# disappearing : 1.3005435e-14
# uncertain : 1.4325723e-14
# informs : 1.511667e-14
# conscience : 1.5735136e-14
# baghdad : 1.4429408e-14
# lifting : 1.3931124e-14
# export : 1.5054003e-14
# insisted : 1.4268809e-14
# flow : 1.5609797e-14
# urgent : 1.4392382e-14
# ensure : 3.4319882e-15
# olympic : 1.569638e-14
# judging : 1.4506535e-14
# eds : 1.4202855e-14
# pairs : 1.4625779e-14
# skating : 1.506417e-14
# dancing : 1.3853116e-14
# olympics : 1.4717596e-14
# tokhtakhounov : 1.3762257e-14
# forte : 1.5996319e-14
# rigging : 1.35020686e-14
# visa : 1.4613233e-14
# alleged : 1.5003896e-14
# mob : 1.4541525e-14
# federation : 1.3774967e-14
# medal : 1.4690699e-14
# dancers : 1.4844037e-14
# jamie : 1.476762e-14
# anissina : 1.568746e-14
# suspended : 1.4400483e-14
# canadian : 1.4673616e-14
# convicted : 1.4994569e-14
# wire : 1.37440515e-14
# fraud : 1.4899747e-14
# faces : 1.4321514e-14
# fbi : 1.6483271e-14
# wiretaps : 1.4164143e-14
# tokhtakhounov's : 1.4055821e-14
# activities : 1.0199537e-07
# explicit : 1.5062389e-14
# gougne : 1.4359069e-14
# gailhaguet : 1.3898215e-14
# comey : 1.4077552e-14
# maxwell : 1.683449e-14
# suspension : 1.4417934e-14
# target : 1.5113873e-14
# collapse : 1.4392328e-14
# implicated : 1.3537192e-14
# smuggling : 1.4479695e-14
# plot : 6.586578e-14
# sports : 1.4837412e-14
# rome : 1.3304128e-14
# traces : 1.347737e-14
# hockey : 1.4253278e-14
# descriptions : 1.4872945e-14
# renewing : 1.4962571e-14
# excerpts : 1.5113096e-14
# mobster : 1.5314944e-14
# dancer : 1.3004916e-14
# satisfaction : 1.3657034e-14
# outcome : 3.6332298e-07
# lining : 1.3427387e-14
# achieved : 1.5595989e-14
# apologized : 1.4065152e-14
# agency : 1.3079743e-14
# infiltrated : 1.3168105e-14
# stunned : 1.3916543e-14
# howard : 1.4838376e-14
# league : 1.3795423e-14
# ward : 1.6998787e-14
# competitors : 1.4023739e-14
# rogers : 1.298739e-14
# conversion : 1.378932e-14
# mailing : 1.532523e-14
# shareholder : 1.3609551e-14
# hotels : 1.470724e-14
# merchant : 1.42074615e-14
# journalists : 1.5164405e-14
# traffickers : 1.3253247e-14
# guerrillas : 1.380095e-14
# colombia : 1.4549988e-14
# colombian : 1.4688122e-14
# takeover : 1.5703027e-14
# assembly : 1.4114494e-14
# el : 1.355794e-14
# claimed : 1.2763428e-14
# gabriel : 1.5081103e-14
# outrage : 1.4814281e-14
# advances : 1.4744541e-14
# regarded : 1.3371749e-14
# cuba : 1.3667197e-14
# cuban : 1.6942206e-14
# castro : 1.4422225e-14
# agent : 1.5492634e-14
# ortega : 1.20782485e-14
# seize : 1.3787583e-14
# destroy : 1.4003908e-14
# handling : 1.35916525e-14
# cartel : 1.2244001e-14
# negotiations : 1.4614876e-14
# jose : 1.318361e-14
# advisers : 1.5546124e-14
# peru : 1.32730546e-14
# civilians : 1.4007807e-14
# austin : 1.37462275e-14
# ibm : 1.424257e-14
# semiconductor : 1.5050586e-14
# factory : 1.4295805e-14
# costly : 1.41741155e-14
# heavily : 1.5927848e-14
# cell : 1.2953473e-14
# phones : 1.502079e-14
# ibm's : 1.4684478e-14
# kelly : 1.2913311e-14
# innovations : 1.5894736e-14
# pataki : 1.3374069e-14
# suppliers : 1.4685713e-14
# innovate : 1.5969188e-14
# storage : 1.4877993e-14
# analysts : 1.2807103e-14
# automated : 1.345043e-14
# diversity : 1.40104255e-14
# custom : 1.4079298e-14
# enclosed : 1.3447301e-14
# stainless : 1.4494699e-14
# steel : 1.2295112e-14
# glass : 1.30896245e-14
# etched : 1.5170741e-14
# width : 1.4110724e-14
# operators : 1.4424454e-14
# monitor : 1.3499959e-14
# efficiency : 1.48027e-14
# shoe : 1.386583e-14
# truck : 1.34140246e-14
# chassis : 1.5366794e-14
# contractor : 1.5398215e-14
# motor : 1.3879642e-14
# angels : 1.4381406e-14
# depth : 1.5303587e-14
# outfielder : 1.1942656e-14
# alex : 1.5328914e-14
# ochoa : 1.536398e-14
# fabregas : 1.327422e-14
# major-league : 1.4522539e-14
# roster : 1.5046539e-14
# deemed : 1.3291142e-14
# hitting : 1.4522925e-14
# homers : 1.5063165e-14
# defender : 1.42794e-14
# bat : 1.2990338e-14
# molina : 1.4796322e-14
# triple-a : 1.3402951e-14
# injured : 1.5280659e-14
# bengie : 1.4964568e-14
# steal : 1.2963185e-14
# catching : 1.4375867e-14
# nl : 1.359497e-14
# struggles : 1.4886396e-14
# friendly : 1.4705585e-14
# md : 1.518956e-14
# firms : 1.3968534e-14
# electronics : 1.4142574e-14
# transmitted : 1.4762324e-14
# stealing : 1.6157921e-14
# secrets : 1.33200225e-14
# sensitive : 1.4938503e-14
# condition : 1.4863472e-14
# chances : 1.4240043e-14
# moreover : 1.5201387e-14
# committees : 1.4665054e-14
# speaker : 1.5508511e-14
# trader : 1.3684674e-14
# via : 1.6210149e-14
# shipping : 1.3584551e-14
# launching : 1.4649006e-14
# dubai : 1.4884437e-14
# prince : 1.5382159e-14
# sheikh : 1.4151155e-14
# website : 1.4103407e-14
# technological : 1.4955895e-14
# headquarters : 1.4478229e-14
# machinery : 1.4020637e-14
# situated : 1.4550764e-14
# transit : 1.4792655e-14
# margin : 1.4952529e-14
# karnes : 1.5947941e-14
# ear : 1.4822421e-14
# tracking : 1.4847547e-14
# bases : 1.3716606e-14
# commanding : 1.3358237e-14
# resist : 1.2970926e-14
# bosses : 1.4135941e-14
# tibbets : 1.5539661e-14
# pilot : 1.4570983e-14
# atomic : 1.35775815e-14
# professor : 1.375024e-14
# suburban : 1.5150124e-14
# civilian : 1.4414361e-14
# engineering : 1.4655044e-14
# hated : 1.4389582e-14
# breeze : 1.4170116e-14
# bombs : 1.31906535e-14
# bubble : 1.4937706e-14
# island : 1.5463762e-14
# tinian : 1.3735771e-14
# hell : 1.4052736e-14
# doctorate : 1.5183711e-14
# anniversary : 1.5184926e-14
# wendover : 1.39348965e-14
# captain : 1.3965309e-14
# landing : 1.411662e-14
# enterprise : 1.3577841e-14
# searching : 1.3176772e-14
# crews : 1.5711596e-14
# isolation : 1.4841828e-14
# thrived : 1.5640823e-14
# admired : 1.346347e-14
# decorated : 1.34226245e-14
# concentrate : 1.5309162e-14
# overnight : 1.4446977e-14
# b-s : 1.5011768e-14
# portions : 1.434634e-14
# arrived : 1.41693586e-14
# flew : 1.657457e-14
# transport : 1.4287137e-14
# cape : 1.5200284e-14
# seattle : 1.6271112e-14
# navy : 1.38118e-14
# tent : 1.477765e-14
# beach : 1.4039502e-14
# distributor : 1.4412354e-14
# stolen : 1.517103e-14
# jealous : 1.4307425e-14
# crew : 1.4004092e-14
# enola : 1.5404356e-14
# intervals : 7.508154e-12
# effects : 1.3273865e-14
# doors : 1.2415627e-14
# climbed : 1.3806953e-14
# cloud : 1.4710635e-14
# woke : 1.4619978e-14
# gen : 1.4522094e-14
# arnold : 1.4697706e-14
# distinguished : 1.3263312e-14
# award : 1.3082961e-14
# unsuspecting : 1.3701728e-14
# pipe : 1.6184013e-14
# carl : 1.3739046e-14
# gathered : 1.5985521e-14
# frustrated : 1.41010394e-14
# carries : 1.3318448e-14
# chemical : 1.5243371e-14
# guilders : 1.6080412e-14
# transactions : 1.3803425e-14
# growth : 1.4112044e-14
# privileges : 1.40422604e-14
# psychologists : 1.4464926e-14
# pills : 1.2028636e-14
# christine : 1.3707766e-14
# legislators : 1.2882709e-14
# prescribe : 1.5809533e-14
# medications : 1.5820151e-14
# psychological : 1.4640824e-14
# apa : 1.5367848e-14
# providers : 1.3630126e-14
# oppose : 1.3275281e-14
# radical : 1.35415555e-14
# psychology : 1.4827596e-14
# psychologist : 1.6281046e-14
# lobby : 1.5173316e-14
# rxp : 1.5713244e-14
# lobbying : 1.5398774e-14
# endorsed : 1.4808121e-14
# independently : 1.5083202e-14
# completing : 1.4217248e-14
# years' : 1.4577932e-14
# clinical : 3.658463e-12
# efficacy : 1.3697835e-14
# developments : 1.6613057e-14
# peculiar : 1.36334535e-14
# abandon : 1.4433867e-14
# argues : 1.461981e-14
# undermine : 1.3687205e-14
# seep : 1.4791806e-14
# expense : 1.3601947e-14
# inadequate : 1.4266552e-14
# philip : 1.3746464e-14
# representative : 1.5420172e-14
# dec : 1.4160766e-14
# accessories : 1.3285034e-14
# cosmetic : 1.469664e-14
# separately : 3.2972233e-13
# posted : 1.4912826e-14
# terminated : 1.358468e-14
# estate : 1.5805886e-14
# ballot : 1.5111798e-14
# attract : 1.40401445e-14
# steady : 1.5664289e-14
# referendum : 1.4345628e-14
# cites : 1.4239203e-14
# launch : 1.4017268e-14
# backing : 1.4266986e-14
# photograph : 1.51851e-14
# collecting : 1.3871836e-14
# variables : 8.0019346e-20
# poorly : 1.4042314e-14
# sotheby's : 1.5350241e-14
# collector : 1.455476e-14
# masters : 1.434831e-14
# photography : 1.5131727e-14
# chatter : 1.3776071e-14
# romance : 1.5587217e-14
# wings : 1.3810852e-14
# charities : 1.4743135e-14
# improving : 1.5574408e-14
# recovery : 1.6532735e-14
# visitors : 1.4612228e-14
# improved : 7.6104607e-13
# appetite : 1.4644985e-14
# therapy : 1.7037609e-14
# coordinator : 1.3820891e-14
# string : 1.2666155e-14
# colored : 1.529139e-14
# dozens : 1.4910551e-14
# protocols : 1.2424084e-14
# diaper : 1.438596e-14
# amid : 1.4735825e-14
# returning : 1.5091578e-14
# cloth : 1.3660368e-14
# gaining : 1.45934e-14
# service's : 1.3682976e-14
# marketing : 1.2085876e-14
# yorkers : 1.3709649e-14
# pillow : 1.4341798e-14
# ratners's : 1.3279182e-14
# oct : 1.4847207e-14
# packaging : 1.37779624e-14
# publishing : 1.2532017e-14
# interim : 1.3191332e-14
# inauguration : 1.5918493e-14
# e-commerce : 1.4687336e-14
# designers : 1.4198819e-14
# state-of-the-art : 1.5044645e-14
# exhibition : 1.4664663e-14
# meridian : 1.48835e-14
# mcalpine : 1.3906062e-14
# arrives : 1.3536443e-14
# route : 1.4177577e-14
# plight : 1.32689795e-14
# suffering : 1.3556752e-14
# chronic : 1.4891793e-14
# reaching : 1.5580587e-14
# mortality : 2.0484007e-18
# barred : 1.3321548e-14
# visited : 1.3596086e-14
# magna : 1.39818085e-14
# frank : 1.3596215e-14
# stronach : 1.3851584e-14
# ambitious : 1.5050671e-14
# excess : 3.306495e-16
# automotive : 1.480304e-14
# enters : 1.4648029e-14
# founder : 1.3977542e-14
# resume : 1.4457175e-14
# ethics : 1.4353236e-14
# panel : 1.3270421e-14
# admonished : 1.5162266e-14
# torricelli : 1.5722358e-14
# accepting : 1.387173e-14
# disclose : 1.3316517e-14
# torricelli's : 1.5128207e-14
# dealings : 1.4036209e-14
# donor : 1.4315069e-14
# chang : 1.4894861e-14
# violations : 1.4118048e-14
# earrings : 1.4609218e-14
# committee's : 1.5571437e-14
# filing : 1.4594124e-14
# forwarded : 1.40732305e-14
# rival : 1.6106843e-14
# recommended : 1.472172e-14
# oregon : 1.4029143e-14
# deliberations : 1.4186342e-14
# businessman : 1.488844e-14
# repayment : 1.5263358e-14
# korean : 1.4912257e-14
# criticized : 1.4032944e-14
# maintaining : 1.3130384e-14
# contacting : 1.5714953e-14
# confirm : 1.5211827e-14
# investigators : 1.3897497e-14
# ranging : 1.2920012e-14
# conducting : 1.426198e-14
# confirmed : 1.3995228e-14
# stern : 1.3620873e-14
# judy : 1.4389253e-14
# rolex : 1.4887986e-14
# clock : 1.6842969e-14
# cite : 1.4532124e-14
# incomplete : 1.1102872e-15
# appliances : 1.5702607e-14
# bronze : 1.435466e-14
# statues : 1.5036554e-14
# displayed : 1.5397717e-14
# discounted : 1.3829593e-14
# banking : 1.4236052e-14
# returns : 1.4923467e-14
# accounted : 1.5542003e-14
# wholly : 1.510105e-14
# powell : 1.4385494e-14
# southeast : 1.5183767e-14
# malaysia : 1.4188586e-14
# singapore : 1.5883282e-14
# touching : 1.311039e-14
# cooperation : 1.4119636e-14
# indonesia : 1.3794845e-14
# links : 1.4349951e-14
# swept : 1.3674446e-14
# blocking : 1.3621757e-14
# recognized : 1.4266822e-14
# forum : 1.39791675e-14
# nam : 1.5239185e-14
# philippines : 1.41052365e-14
# pentagon : 1.4179254e-14
# reviewing : 1.3909934e-14
# renewed : 1.4068909e-14
# foster : 1.463848e-14
# ambiguities : 1.4576124e-14
# suspected : 1.37351415e-14
# ibrahim : 1.501569e-14
# wan : 1.2421217e-14
# announce : 1.4443367e-14
# microsoft's : 1.4817164e-14
# carriers : 1.4605262e-14
# persuade : 1.4948595e-14
# desktop : 1.4892843e-14
# pc : 1.34800686e-14
# partnerships : 1.4252244e-14
# floyd : 1.2821279e-14
# sox : 1.5988877e-14
# cliff : 1.4376031e-14
# pivotal : 1.6148861e-14
# expos : 1.36215485e-14
# minaya : 1.4539612e-14
# obtained : 1.527428e-14
# acquiring : 1.508142e-14
# prudent : 1.4015985e-14
# song : 1.3583074e-14
# realization : 1.4663573e-14
# evident : 5.4234804e-18
# starke : 1.4283159e-14
# two-year : 1.570725e-14
# attracted : 1.5054462e-14
# coordinated : 1.4936452e-14
# fund-raising : 1.4017402e-14
# super : 1.3906964e-14
# gibbs : 1.4548155e-14
# hill : 1.33077075e-14
# gang : 1.4162494e-14
# dire : 1.4741306e-14
# matched : 1.4838091e-14
# forty : 1.36821156e-14
# enrolled : 1.5262863e-14
# housing : 1.3651356e-14
# kicked : 1.5428881e-14
# threatening : 1.39275095e-14
# dedication : 1.4634319e-14
# flapping : 1.360296e-14
# skill : 1.4525863e-14
# grateful : 1.3085082e-14
# workshop : 1.5245551e-14
# rebuilt : 1.528687e-14
# millennium : 1.4332445e-14
# rebuilding : 1.5001377e-14
# auctioned : 1.3878743e-14
# lone : 1.3505521e-14
# 'the : 1.33279525e-14
# auction : 1.6907343e-14
# eagle : 1.3136346e-14
# sting : 1.3802134e-14
# operation : 1.4103917e-14
# anonymous : 1.3734722e-14
# collectors : 1.4403971e-14
# seemingly : 1.41344295e-14
# bidding : 1.5838991e-14
# ebay : 1.5110848e-14
# houses : 1.457532e-14
# seasons : 1.4594986e-14
# unprecedented : 1.4280298e-14
# mint : 1.4659742e-14
# fenton : 1.2763353e-14
# satisfying : 1.5709617e-14
# customary : 1.40290366e-14
# managing : 1.3265917e-14
# fruit : 1.5551344e-14
# betting : 1.4477789e-14
# pools : 1.4026495e-14
# burst : 1.3665268e-14
# louder : 1.641926e-14
# explosion : 1.5001863e-14
# sounded : 1.586923e-14
# attendance : 1.5244708e-14
# rush : 1.5267347e-14
# boom : 1.4033693e-14
# eagles : 1.4687785e-14
# mid-s : 1.3955989e-14
# vault : 1.4399e-14
# collapsed : 1.7630183e-14
# certificate : 1.4210849e-14
# fee : 1.352875e-14
# cd : 1.4501114e-14
# retail : 1.5245843e-14
# evidenced : 1.3576417e-14
# consequently : 1.4867895e-14
# disclosure : 1.4406884e-14
# governing : 1.4204617e-14
# mccall : 1.4589504e-14
# images : 1.4231871e-14
# lieutenant : 1.3386958e-14
# comptroller : 1.2115811e-14
# advertisement : 1.567998e-14
# camera : 1.2982017e-14
# citibank : 1.6605202e-14
# skilled : 1.3945214e-14
# counters : 1.38494164e-14
# emphasizing : 1.2897434e-14
# nelson : 1.4009596e-14
# investigator : 1.4288174e-14
# nelson's : 1.35960596e-14
# sheet : 1.2542921e-14
# ruling : 1.4787349e-14
# upheld : 1.5109406e-14
# garden : 1.4827454e-14
# constitute : 1.5155644e-14
# cruel : 1.7340076e-14
# ambiguous : 1.3888779e-14
# acceptable : 1.2941568e-14
# exotic : 1.3505726e-14
# warrant : 1.39346856e-14
# dining : 1.617673e-14
# blind : 1.6379972e-14
# christians : 1.4702191e-14
# dynasty : 1.54013e-14
# demanded : 1.5083893e-14
# governance : 1.3858824e-14
# opportunities : 1.5360024e-14
# propaganda : 1.4859843e-14
# protests : 1.4792655e-14
# responding : 1.3526377e-14
# designs : 1.5362047e-14
# port : 1.5798532e-14
# footage : 1.4076505e-14
# transportation : 1.5283226e-14
# repair : 1.4195733e-14
# path : 1.3377973e-14
# lowering : 1.4185583e-14
# legacy : 1.3447481e-14
# crippling : 1.3547601e-14
# jeffords : 1.4259586e-14
# pollutants : 1.6177933e-14
# nitrogen : 1.4889094e-14
# sulfur : 1.3715744e-14
# acid : 1.5243952e-14
# mercury : 1.4155258e-14
# emissions : 1.3583929e-14
# mechanisms : 1.30964685e-14
# market-based : 1.5529053e-14
# disappear : 1.3833023e-14
# parks : 1.3663208e-14
# upgrade : 1.41643585e-14
# thoughtful : 1.4844717e-14
# improvement : 1.4900231e-14
# lama : 1.6200877e-14
# equus : 1.426813e-14
# leather : 1.3326478e-14
# accrue : 1.4593456e-14
# promptly : 1.2856101e-14
# duty-free : 1.4204995e-14
# imports : 1.3827351e-14
# watches : 1.3476753e-14
# islands : 1.3897869e-14
# classifications : 1.4786278e-14
# categories : 3.5025017e-12
# producer : 1.4242217e-14
# incorporated : 1.5238312e-14
# netherlands : 1.4049172e-14
# advertised : 1.3333062e-14
# dow : 1.3998833e-14
# telerate : 1.38985325e-14
# est : 1.4868433e-14
# merged : 1.3346115e-14
# primerica : 1.4395843e-14
# ga : 1.5962365e-14
# associates : 1.5280457e-14
# assumed : 1.3994134e-14
# mortgage : 1.3633845e-14
# upjohn : 1.3346522e-14
# resulting : 1.2650872e-14
# implement : 1.493047e-14
# jonathan : 1.624999e-14
# waertsilae : 1.6146552e-14
# ships : 1.2838482e-14
# participants : 1.4564676e-14
# marine's : 1.5745316e-14
# accord : 1.34250055e-14
# intelogic : 1.4698266e-14
# ackerman : 1.4621652e-14
# edelman : 1.4296024e-14
# affiliate : 1.3684908e-14
# announcement : 1.4080506e-14
# retain : 1.3685561e-14
# banker : 1.576518e-14
# marty : 1.4435822e-14
# northeastern : 1.443786e-14
# revive : 1.4307152e-14
# essay : 1.4858142e-14
# xxxxxxxxx : 1.3814592e-14
# alexis : 1.3808006e-14
# youngstown : 1.445417e-14
# tube : 1.5317398e-14
# mahoning : 1.2274351e-14
# struthers : 1.4695407e-14
# boardman : 1.5476391e-14
# villages : 1.4392052e-14
# mills : 1.41476466e-14
# snatched : 1.3595101e-14
# factories : 1.4582382e-14
# petitions : 1.3621913e-14
# attempted : 1.4379679e-14
# regionalism : 1.6595701e-14
# blast : 1.3480892e-14
# railway : 1.5058913e-14
# chicago : 1.4111802e-14
# bridge : 1.5894192e-14
# shifted : 1.5036383e-14
# northeast : 1.4932977e-14
# youngstowns : 1.3862393e-14
# grown : 1.4065475e-14
# doubled : 1.4489501e-14
# survived : 1.3635586e-14
# booming : 1.4624412e-14
# bloody : 1.5863967e-14
# experimental : 1.322827e-14
# negotiating : 1.38519e-14
# prohibited : 1.488458e-14
# governmental : 1.5385915e-14
# updated : 1.5035751e-14
# industrys : 1.3283134e-14
# recipe : 1.252499e-14
# ruin : 1.4238443e-14
# powers : 1.4732312e-14
# uswa : 1.4861203e-14
# cant : 1.467065e-14
# adjoining : 1.4106042e-14
# couldnt : 1.4639511e-14
# residential : 1.4352142e-14
# shrank : 1.4202476e-14
# considerably : 1.4898468e-14
# inhabited : 1.5394136e-14
# escape : 1.3886554e-14
# carter : 1.3971145e-14
# dried : 1.5219866e-14
# invested : 1.4502442e-14
# updating : 1.4653145e-14
# hikes : 1.2788453e-14
# improve : 1.145634e-19
# draining : 1.3776491e-14
# newer : 1.425045e-14
# aluminum : 1.4068345e-14
# substitute : 1.4648252e-14
# fierce : 1.5077739e-14
# inferior : 1.5078255e-14
# citys : 1.4219904e-14
# urgency : 1.3476059e-14
# confront : 1.4879582e-14
# heating : 1.4942266e-14
# donations : 1.3751028e-14
# lacked : 1.376378e-14
# concrete : 1.31057385e-14
# socialism : 1.4629182e-14
# waited : 1.5526419e-14
# towards : 1.4839477e-14
# packed : 1.5570902e-14
# casual : 1.4099426e-14
# dependent : 1.4235998e-14
# cultural : 1.5026636e-14
# orthodox : 1.3821524e-14
# blocks : 1.3925597e-14
# concentration : 1.5612298e-14
# respective : 1.4537864e-14
# populations : 1.5439654e-14
# dictates : 1.5368552e-14
# habits : 1.4276349e-14
# interactions : 1.4839536e-14
# bizarre : 1.3284198e-14
# enemies : 1.41791986e-14
# futures : 1.5218736e-14
# devastating : 1.2981545e-14
# catastrophe : 1.3949523e-14
# conspicuous : 1.3817175e-14
# tightly : 1.5098516e-14
# prof : 1.4223513e-14
# revitalization : 1.4581715e-14
# movements : 1.5297078e-14
# humans : 1.5648908e-14
# broadly : 1.4779398e-14
# characteristics : 1.3794397e-14
# traits : 1.3523255e-14
# lifestyle : 1.2698352e-14
# dominant : 1.4316544e-14
# guaranteed : 1.477906e-14
# maya : 1.3690208e-14
# guatemala : 1.41695195e-14
# nasa : 1.5356716e-14
# guambiano : 1.6124363e-14
# attain : 1.31915336e-14
# embedded : 1.4333483e-14
# possessed : 1.36539865e-14
# jackson : 1.4388101e-14
# conservatives : 1.4155258e-14
# ongoing : 1.437444e-14
# mountainous : 1.3336344e-14
# mayans : 1.4625166e-14
# overwhelming : 1.3272143e-14
# mayan : 1.5163335e-14
# pan-mayan : 1.3773129e-14
# guatemalan : 1.5451644e-14
# modernity : 1.459752e-14
# mobility : 1.461482e-14
# renaissance : 1.5252212e-14
# fractured : 1.4584495e-14
# sole : 1.5855071e-14
# consciousness : 1.5173982e-14
# gow : 1.4223459e-14
# corporal : 1.392998e-14
# illiteracy : 1.398837e-14
# literate : 1.4865515e-14
# cosmovision : 1.3567589e-14
# translate : 1.4389418e-14
# permanent : 1.4745836e-14
# harmonic : 1.4396363e-14
# researchers : 1.4274035e-14
# perception : 1.5466181e-14
# harmony : 1.4254175e-14
# influenced : 1.5396455e-14
# workshops : 1.4459823e-14
# regain : 1.5213018e-14
# mode : 1.3187056e-14
# gateway : 1.4635686e-14
# appearing : 1.561486e-14
# develops : 1.351949e-14
# kay : 1.38893625e-14
# revival : 1.4205077e-14
# pp : 1.5980522e-14
# boulder : 1.28271984e-14
# harvester : 1.3710434e-14
# ant : 1.3609136e-14
# robot : 1.4347022e-14
# colony : 1.4322306e-14
# infiltration : 1.35587164e-14
# insect : 1.5080241e-14
# simpler : 4.9548093e-13
# insects : 1.4990737e-14
# ants : 1.386554e-14
# robots : 1.447478e-14
# undetected : 1.2959082e-14
# performing : 1.2995741e-14
# behaviors : 1.5072101e-14
# constructed : 1.4048316e-14
# thresholds : 1.3329782e-14
# stimulation : 1.38457725e-14
# task-switching : 1.34700965e-14
# hereafter : 1.4391174e-14
# antie : 1.4324027e-14
# nest : 1.4074116e-14
# foraging : 1.4029705e-14
# patrolling : 1.33045345e-14
# midden : 1.5101396e-14
# nests : 1.5054864e-14
# deposited : 1.4080157e-14
# forage : 1.409593e-14
# gordon : 1.4718634e-14
# grasses : 1.545875e-14
# creatures : 1.2866477e-14
# animals : 1.6434423e-14
# equipped : 1.4641298e-14
# navigate : 1.4460292e-14
# sandy : 1.3401545e-14
# soil : 1.3868292e-14
# breeding : 1.6405453e-14
# queens : 1.5560393e-14
# deepest : 1.4073874e-14
# seed : 1.4004734e-14
# dirt : 1.37654585e-14
# garbage : 1.5250232e-14
# extensively : 1.4434361e-14
# ex : 1.5503336e-14
# schafer : 1.49266e-14
# depths : 1.4108385e-14
# overlap : 5.0356853e-18
# deposit : 1.3555252e-14
# halfway : 1.4782048e-14
# mound : 1.4506315e-14
# stimulated : 1.5271687e-14
# sub-behaviors : 1.4736584e-14
# exit : 1.6003886e-14
# wander : 1.3328765e-14
# humidity : 1.6846696e-14
# degradation : 1.5518482e-14
# patrollers : 1.4599246e-14
# cuticular : 1.30584545e-14
# hydrocarbons : 1.5531305e-14
# heat : 1.4662145e-14
# foragers : 1.5131093e-14
# patroller : 1.2730313e-14
# inactive : 1.4638506e-14
# discovery : 1.5440213e-14
# accomplished : 1.4696808e-14
# gland : 1.4387663e-14
# drags : 1.4391037e-14
# trails : 1.3517711e-14
# tasks : 1.459418e-14
# nestmate : 1.4903953e-14
# warrior : 1.2862722e-14
# interactive : 1.6817546e-14
# pseudocode : 1.7302215e-14
# sensors : 1.4427783e-14
# thermometer : 1.33862936e-14
# bump : 1.538436e-14
# polarization : 1.39621404e-14
# compass : 1.5601464e-14
# receptors : 1.423673e-14
# circular : 1.4591118e-14
# cm : 1.4106554e-14
# wheels : 1.4883841e-14
# rear : 1.4055981e-14
# wheel : 1.31247e-14
# elongated : 1.3237659e-14
# skirt : 1.30776974e-14
# sonar : 1.3327419e-14
# detectors : 1.4664719e-14
# pheromones : 1.438692e-14
# determines : 1.32835645e-14
# powered : 9.657891e-15
# fig : 1.4045021e-14
# inform : 1.41311675e-14
# stalks : 1.4603592e-14
# antennae : 1.337874e-14
# grippers : 1.3171597e-14
# locations : 1.5082342e-14
# degrees : 1.3828301e-14
# celsius : 1.5519372e-14
# gradient : 1.38645885e-14
# enable : 1.4166089e-14
# in-nest : 1.4404136e-14
# navigation : 1.5491335e-14
# photoreceptor : 1.5060664e-14
# initiate : 1.4491602e-14
# depressed : 1.4482705e-14
# detection : 1.6228214e-14
# orient : 1.5130024e-14
# cells : 1.5057075e-14
# integration : 1.4559092e-14
# labhart : 1.5203067e-14
# lambrinos : 1.3794423e-14
# photodiodes : 1.5380782e-14
# filters : 1.4934971e-14
# sky : 1.4835375e-14
# analytical : 1.519182e-14
# diagram : 1.4768802e-14
# ratio : 1.565712e-14
# sensing : 1.3958706e-14
# interact : 1.4904693e-14
# n-alkene : 1.409308e-14
# indicates : 1.6380907e-14
# altered : 1.61892e-14
# n-alkanes : 1.34771124e-14
# hydrocarbon : 1.3502766e-14
# profile : 1.4573151e-14
# anties : 1.3624667e-14
# piles : 1.4605208e-14
# trash : 1.5164782e-14
# olfactory : 1.4907138e-14
# removing : 1.5025546e-14
# pheromone : 1.3347185e-14
# arranged : 1.4466803e-14
# receptor : 1.4856499e-14
# technique : 1.22877265e-14
# abilities : 1.5044186e-14
# layers : 1.4801064e-14
# muscles : 1.4542717e-14
# engaging : 1.615718e-14
# forager : 1.3131287e-14
# operated : 1.4937194e-14
# simultaneously : 1.6557509e-14
# glands : 1.6880018e-14
# spray : 1.5995465e-14
# alter : 1.4565536e-14
# architecture : 1.4420465e-14
# ...
# ficlet : 1.3488942e-14
# ow : 1.40862e-14
# marzark : 1.5286519e-14
# mackizme : 1.5247325e-14
# owen : 1.2690095e-14
# goodbye : 1.4143815e-14
# stealth : 1.4751236e-14
# amazed : 1.4163873e-14
# eyed : 1.4515948e-14
# she'd : 1.4678178e-14
# marie : 1.423752e-14
# shivered : 1.3239654e-14
# palms : 1.3877128e-14
# deductions : 1.5467066e-14
# pathway : 1.429049e-14
# strode : 1.42176e-14
# bonfire : 1.4116001e-14
# jeans : 1.5176906e-14
# archie : 1.6081119e-14
# wilber : 1.4649455e-14
# panties : 1.527288e-14
# alias : 1.3757113e-14
# slime : 1.3684516e-14
# whites : 8.4806234e-05
# gravity : 1.4900883e-14
# slid : 1.7156244e-14
# stared : 1.4692437e-14
# numbered : 1.2818393e-14
# glances : 1.4266224e-14
# brow : 1.3236623e-14
# button : 1.457304e-14
# hes : 1.4047351e-14
# blinked : 1.4330149e-14
# yells : 1.3337768e-14
# slams : 1.3838776e-14
# yelling : 1.4297606e-14
# blusparrow : 1.4156553e-14
# janice : 1.5066814e-14
# janices : 1.4142089e-14
# kyle : 1.5040801e-14
# sweat : 1.8039186e-14
# amber : 1.4666453e-14
# replies : 1.28182716e-14
# pulls : 1.4626506e-14
# waiter : 1.3834474e-14
# draped : 1.2806565e-14
# jeffery : 1.4740913e-14
# beg : 1.28215725e-14
# bella : 1.2777043e-14
# greyhem : 1.419771e-14
# chased : 1.41966805e-14
# robe : 1.3674551e-14
# bowed : 1.450413e-14
# clipboard : 1.5240928e-14
# slowed : 1.5151944e-14
# bonesetter : 1.4929447e-14
# frowned : 1.4188451e-14
# ipsum : 1.3891535e-14
# dolor : 1.5981924e-14
# amet : 1.38933105e-14
# sed : 1.3360047e-14
# erat : 1.5181566e-14
# nulla : 1.4951646e-14
# eget : 1.3659951e-14
# rabbit : 1.4019192e-14
# paused : 1.4463933e-14
# shes : 1.5233052e-14
# todd : 1.5117188e-14
# waved : 1.4980676e-14
# grabs : 1.5700213e-14
# amazement : 1.448055e-14
# den : 1.4146621e-14
# flashed : 1.3450019e-14
# whistle : 1.4907992e-14
# moses : 1.447812e-14
# despair : 1.5231745e-14
# spouse : 1.4527027e-14
# typetitlethe : 1.3440531e-14
# skydiving : 1.4319e-14
# squat : 1.5303439e-14
# vodka : 1.5030161e-14
# smelled : 1.41632786e-14
# multiply : 1.3465935e-14
# rite : 1.4028153e-14
# hermit : 1.3483796e-14
# jumps : 1.3695275e-14
# tonto : 1.4909982e-14
# cowboy : 1.4868122e-14
# kursk : 1.38780275e-14
# sank : 1.4476574e-14
# torpedo : 1.4813885e-14
# seaman : 1.460426e-14
# reboot : 1.430366e-14
# aye : 1.3374937e-14
# overboard : 1.4661419e-14
# doomed : 1.5400595e-14
# starboard : 1.3788322e-14
# slammed : 1.3345555e-14
# policeman : 1.480767e-14
# sadie : 1.5185564e-14
# saucer : 1.4627509e-14
# proprietor : 1.451484e-14
# mice : 1.3464446e-14
# typetitlea : 1.33714425e-14
# mace : 1.5043153e-14
# mechanic : 1.526391e-14
# paradox : 1.5712014e-14
# cholesterol : 8.968024e-11
# whatsamatta : 1.573805e-14
# tray : 1.5561164e-14
# stool : 1.3044166e-14
# cakes : 1.2688981e-14
# ale : 1.4308135e-14
# organ : 1.3489457e-14
# pig : 1.4306661e-14
# childbirth : 1.3653232e-14
# fisherman : 1.5640136e-14
# robbed : 1.6433013e-14
# cannibals : 1.2838923e-14
# aggi : 1.3402185e-14
# goat : 1.4568426e-14
# toast : 1.4493953e-14
# slaps : 1.4364903e-14
# grinned : 1.3274953e-14
# coffin : 1.4586387e-14
# dialed : 1.4553928e-14
# bow : 1.6190808e-14
# accidents : 1.4867498e-14
# prayed : 1.423836e-14
# rowboat : 1.2981644e-14
# rabbits : 1.3755538e-14
# limb : 1.3392243e-14
# cheque : 1.5211827e-14
# calculations : 6.4550665e-07
# communicated : 1.42077326e-14
# donkey : 1.3677549e-14
# shovel : 1.4120176e-14
# spotted : 1.4506647e-14
# bartender : 1.5787507e-14
# ape : 1.4195841e-14
# panty : 1.4093995e-14
# 'er : 1.3639437e-14
# glared : 1.4740659e-14
# sneeze : 1.4490718e-14
# ashes : 1.3233165e-14
# leopard : 1.4419858e-14
# halts : 1.4091951e-14
# pans : 1.5712915e-14
# arrow : 1.2387881e-14
# closes : 1.5557663e-14
# impulse : 1.4831894e-14
# proportional : 6.825272e-11
# ski : 1.4239772e-14
# melvin : 1.4115141e-14
# puzzled : 1.4231953e-14
# prefix : 1.3423596e-14
# stored : 1.5277949e-14
# lighted : 1.3686004e-14
# djs : 1.5433001e-14
# pews : 1.431272e-14
# glanced : 1.4905147e-14
# velvet : 1.440683e-14
# nepthys : 1.3840967e-14
# bark : 1.3551063e-14
# claws : 1.40168935e-14
# hunchback : 1.4104374e-14
# dvorov : 1.5942983e-14
# dvorovs : 1.3607812e-14
# cart : 1.5648432e-14
# slave : 1.2393481e-14
# leech : 1.3332529e-14
# isis : 1.551215e-14
# liquid : 1.3067423e-14
# twitched : 1.446181e-14
# hoped : 1.4770662e-14
# stakes : 1.5274687e-14
# strobe : 1.4482927e-14
# tentacles : 1.4335863e-14
# cage : 1.3384251e-14
# statistically : 1.4570239e-17
# wreck : 1.4537588e-14
# lightscreen : 1.4779849e-14
# plates : 1.4813322e-14
# sarah's : 1.4275316e-14
# couches : 1.3820312e-14
# kishori : 1.4992109e-14
# adrienne : 1.4405235e-14
# captain's : 1.4266224e-14
# cohort : 1.4346778e-10
# ninety-nine : 1.3840756e-14
# exchanged : 1.3367159e-14
# sideways : 1.5401947e-14
# spears : 1.4033024e-14
# arrallin : 1.3883537e-14
# willow : 1.5547725e-14
# lantern : 1.5274105e-14
# lantern's : 1.4686777e-14
# skeleton : 1.4574652e-14
# muscle : 1.2548879e-14
# allan's : 1.3649169e-14
# arthur's : 1.3683838e-14
# unhealthy : 8.3434865e-12
# morbidity : 2.921528e-10
# wisest : 1.4392877e-14
# probation : 1.6671655e-14
# spear : 1.5112347e-14
# thorndike : 1.4106634e-14
# isaacs : 1.4819876e-14
# flung : 1.4373617e-14
# prisoners : 1.32020546e-14
# stopbox : 1.5236017e-14
# capturador : 1.4745919e-14
# stopboxes : 1.574129e-14
# mindwipe : 1.3215282e-14
# vega : 1.5105488e-14
# tasha : 1.3618925e-14
# cortez : 1.3707452e-14
# flynn : 1.5042406e-14
# bernardo : 1.5658016e-14
# tasha's : 1.4458747e-14
# malaquez : 1.5406354e-14
# imbalance : 1.4938163e-14
# accents : 1.4277603e-14
# interchange : 1.2882709e-14
# nardo : 1.3646384e-14
# emil : 1.5356773e-14
# malaquez's : 1.3148078e-14
# rica : 1.33253334e-14
# malcolm : 1.3341788e-14
# horatio : 1.372697e-14
# cont'd : 1.3456743e-14
# marines : 1.4956522e-14
# dinosaurs : 1.3402747e-14
# t-rexes : 1.3049816e-14
# t-rex : 1.5017093e-14
# ingen : 1.5134153e-14
# spinosaur : 1.3522714e-14
# isla : 1.453778e-14
# sorna : 1.3811377e-14
# hammond : 1.668839e-14
# roland : 1.3452381e-14
# tembo : 1.4208275e-14
# rexes : 1.2826586e-14
# cpl : 1.4288555e-14
# townsend : 1.4988107e-14
# sattler : 1.4649455e-14
# ellie : 1.355882e-14
# lysine : 1.5142989e-14
# roland's : 1.4693782e-14
# ernst : 1.3854225e-14
# tambala : 1.3237633e-14
# melina : 1.5966873e-14
# lt : 1.3610434e-14
# brannigan : 1.5575091e-14
# rowing : 1.460114e-14
# manacles : 1.2212351e-14
# swann : 1.3905903e-14
# cutler : 1.3395847e-14
# norrington : 1.36398e-14
# oar : 1.4776747e-14
# gibbs' : 1.489952e-14
# jack's : 1.3911261e-14
# cotton's : 1.527626e-14
# awk : 1.2798459e-14
# snarls : 1.2918583e-14
# crewman : 1.3926129e-14
# unlocks : 1.5093737e-14
# will's : 1.4036637e-14
# marque : 1.4158227e-14
# upside-down : 1.5321898e-14
# bootstrap : 1.3239376e-14
# crab : 1.374877e-14
# dutchman : 1.2627271e-14
# mast : 1.248966e-14
# euh : 1.4078249e-14
# agh : 1.5095838e-14
# o' : 1.4735825e-14
# shhh : 1.4855196e-14
# crewmember : 1.2774802e-14
# underwater : 1.4753542e-14
# tortuga : 1.4153961e-14
# giselle : 1.398058e-14
# 'im : 1.34427364e-14
# cannibal : 1.4764015e-14
# spyglass : 1.4879696e-14
# lam : 1.4619867e-14
# longboat : 1.4222725e-14
# ragetti : 1.4673784e-14
# pintel : 1.5473617e-14
# must've : 1.424776e-14
# crewmen : 1.4909242e-14
# chasm : 1.39071765e-14
# bugger : 1.5267522e-14
# coconut : 1.3741011e-14
# ragetti's : 1.4941012e-14
# departing : 1.35721444e-14
# davy : 1.4302678e-14
# edinburgh : 1.4021492e-14
# bellamy : 1.4566758e-14
# bursar : 1.4274499e-14
# quartermaster : 1.581291e-14
# kraken : 1.5432795e-14
# tia's : 1.478515e-14
# tia : 1.3208351e-14
# dalma : 1.538037e-14
# wid : 1.3427924e-14
# scuttled : 1.5327334e-14
# reef : 1.30723094e-14
# crewmembers : 1.4334852e-14
# swordfight : 1.4487567e-14
# maccus : 1.5990158e-14
# jones' : 1.3720741e-14
# commodore : 1.41729805e-14
# heave : 1.3494475e-14
# bo'sun : 1.4951131e-14
# tentacle : 1.4086227e-14
# wyvern : 1.4368438e-14
# loading : 1.421375e-14
# shackles : 1.2564374e-14
# koleniko : 1.5483478e-14
# elizabeth's : 1.31257776e-14
# cruces : 1.5597238e-14
# duel : 1.4381928e-14
# swords : 1.352194e-14
# hadrus : 1.4975019e-14
# hadrus' : 1.5986436e-14
# aunido : 1.40717e-14
# kraken's : 1.4163791e-14
# gunpowder : 1.2766982e-14
# docnolists-- : 1.33337e-14
# namedave : 1.2521957e-14
# raggett : 1.434311e-14
# emaildsrworg : 1.5329147e-14
# senttue : 1.4388293e-14
# idaaworg : 1.4324137e-14
# wc-math-erbworg : 1.3634363e-14
# raman : 1.4313815e-14
# whitney : 1.4232903e-14
# soiffer : 1.361085e-14
# bruce's : 1.3630282e-14
# sgml : 1.4178442e-14
# html-math : 1.3025072e-14
# latex : 1.5194023e-14
# tex : 1.544861e-14
# numbering : 1.35849135e-14
# math-erb : 1.4036049e-14
# netscape : 1.5175371e-14
# subexpression : 1.525096e-14
# subexpressions : 1.2361421e-14
# dsrworg : 1.4456598e-14
# consortium : 1.558558e-14
# httpwwwworgpeopleraggett : 1.4059252e-14
# patti : 1.5991955e-14
# stevenkeanenroncom : 1.3246196e-14
# abx : 1.4377705e-14
# mime-version : 1.3445224e-14
# content-type : 1.3381673e-14
# textplain : 1.5099956e-14
# charsetus-ascii : 1.37616266e-14
# content-transfer-encoding : 1.6126547e-14
# x-from : 1.406746e-14
# kean : 1.4385193e-14
# x-to : 1.3914526e-14
# x-cc : 1.4197113e-14
# x-bcc : 1.5211655e-14
# x-folder : 1.3963046e-14
# stevenkeanjunenotes : 1.4672469e-14
# foldersall : 1.3027209e-14
# x-origin : 1.5356597e-14
# kean-s : 1.3722468e-14
# x-filename : 1.4465918e-14
# skeannsf : 1.5123274e-14
# keannaenron : 1.4568843e-14
# skeanenroncom : 1.5224862e-14
# receivedtue : 1.4191672e-14
# sentwed : 1.4384754e-14
# subjectre : 1.228433e-14
# charset : 1.2809473e-14
# trothricevmriceedu : 1.3252008e-14
# troth : 1.6895673e-14
# scsadammitedu : 1.4644371e-14
# pine-infocacwashingtonedu : 1.3070839e-14
# ietf-charsetsinnosoftcom : 1.4460735e-14
# javamailevansthyme : 1.2859484e-14
# jkaminskienroncom : 1.6138578e-14
# wbalsoncraicom : 1.5261057e-14
# vince : 1.4378664e-14
# message----- : 1.3624616e-14
# balson : 1.4510992e-14
# tokaminski : 1.4096092e-14
# vincejkaminskienroncom : 1.4181958e-14
# kaminski : 1.4683331e-14
# nametom : 1.4552319e-14
# emailtomstemicrosoftcom : 1.38358995e-14
# sentfri : 1.4432957e-14
# ietf-tlsworg : 1.4565646e-14
# tls-draftworg : 1.3869402e-14
# tls-draft : 1.56176e-14
# stlp : 1.4413233e-14
# strawman : 1.379474e-14
# ietf : 1.2585481e-14
# treese : 1.4466748e-14
# dsteffesenroncom : 1.4208166e-14
# enron's : 1.5665932e-14
# nico : 1.4888752e-14
# wolfram : 1.5292643e-14
# pannesleyriskwaterscom : 1.40955e-14
# annesley : 1.5254132e-14
# pannesleyriskwaterscomenron : 1.3578048e-14
# mailtovincejkaminskienroncom : 1.505693e-14
# wolak : 1.3464599e-14
# mailtoimceanotes-philipannesleycpannesleyriskwatersecom : 1.3937343e-14
# eenronenroncom : 1.508706e-14
# vkaminskiaolcom : 1.5274628e-14
# vkaminsenroncom : 1.4069633e-14
# programme : 1.4180335e-14
# wwwrisk-conferencescomriskaus : 1.3849602e-14
# receivedmon : 1.4258009e-14
# sentmon : 1.4216731e-14
# bof : 1.6265775e-14
# kevinscottonlinemailboxnet : 1.4066172e-14
# jeffskillingenroncom : 1.5285179e-14
# andersen : 1.38139605e-14
# bcc : 1.485735e-14
# skilling : 1.37892136e-14
# wto : 1.530484e-14
# sanjay : 1.4114117e-14
# cii : 1.3096069e-14
# sudaker : 1.599339e-14
# charsets : 1.4319629e-14
# rfc : 1.3201501e-14
# smtp : 1.4517969e-14
# ascii : 1.3106113e-14
# iso-- : 1.5197096e-14
# lf : 1.438179e-14
# us-ascii : 1.5048777e-14
# canonical : 1.6608908e-14
# mime : 1.38864225e-14
# sandersjamestandemcom : 1.37782775e-14
# pct : 1.4848369e-14
# lundblade : 1.2813603e-14
# crispin : 1.3706146e-14
# pinerc : 1.3524983e-14
# iso--jp : 1.375024e-14
# iso--x : 1.5336575e-14
# ph : 1.4865515e-14
# stj-xlssee : 1.5186838e-14
# stj-xls : 1.2137507e-14
# vincekaminskienroncom : 1.6082345e-14
# poppelier : 1.4603758e-14
# sentthu : 1.4631305e-14
# fonts : 1.2672026e-14
# ams : 1.4636607e-14
# elsevier : 1.36770546e-14
# '' : 1.4171981e-14
# equations : 1.512763e-14
# sub-figures : 1.5819789e-14
# npoppelierelseviernl : 1.4939388e-14
# parsing : 1.3191383e-14
# ramanadobecom : 1.3639489e-14
# embellishments : 1.5262134e-14
# precedence : 1.665284e-14
# harald : 1.5399479e-14
# tveit : 1.3397711e-14
# alvestrand : 1.5489739e-14
# postfix : 1.3683864e-14
# embellishment : 1.4068909e-14
# karthik : 1.3953648e-14
# notation : 1.3006899e-14
# benjaminrogersenroncom : 1.4306771e-14
# eprovisioning : 1.5387089e-14
# agrement : 1.3151589e-14
# blacklined : 1.454233e-14
# vdoc : 1.374801e-14
# aster : 1.3293678e-14
# substitution : 1.431709e-14
# brulte : 1.4701295e-14
# charsetansix- : 1.5420289e-14
# dasovich : 1.3533526e-14
# siting : 1.4026174e-14
# dwr : 1.3636133e-14
# puc : 1.5214235e-14
# dwrs : 1.4285939e-14
# mw : 1.5083893e-14
# sbx : 1.4275588e-14
# supply-demand : 1.4523869e-14
# concur : 1.4079648e-14
# stevenjkeanenroncom : 1.5230582e-14
# ucs : 1.364386e-14
# integrals : 1.5669996e-14
# nber : 1.3401316e-14
# shirleycrenshawenroncom : 1.36079155e-14
# crenshaw : 1.432862e-14
# jingming : 1.3388031e-14
# krishnarao : 1.4877993e-14
# pinnamaneni : 1.3553391e-14
# krishna : 1.3258633e-14
# kaminskienronenronxgate : 1.3682794e-14
# ios : 1.4135183e-14
# unilateral : 1.4347488e-14
# stockdale : 1.5928304e-14
# sjgren's : 1.5214846e-14
# ss : 1.4300987e-14
# autoimmune : 1.36673e-14
# sicca : 1.4937592e-14
# non-exocrine : 1.3466808e-14
# kidney : 1.2548257e-14
# liver : 1.4317608e-14
# abnormalities : 1.3798528e-14
# biliary : 1.4666398e-14
# cirrhosis : 1.5101224e-14
# hepatitis : 1.434415e-14
# viral : 1.4254092e-14
# prevalence : 1.5423347e-14
# abnormal : 1.3886554e-14
# lfts : 1.3866096e-14
# salivary : 1.5855254e-14
# biopsy : 1.40212794e-14
# diagnosis : 1.4823553e-14
# labial : 1.3317636e-14
# serological : 1.2684288e-14
# situ : 1.3969279e-14
# hybridization : 1.4395403e-14
# hepatic : 1.3321242e-14
# cholestatic : 1.3535436e-14
# hcv : 1.3428488e-14
# infection : 1.465292e-14
# epithelial : 1.30594515e-14
# tissue : 1.4093725e-14
# pathogenesis : 1.4757201e-14
# glutamate : 1.2958365e-14
# gad : 1.4821742e-14
# gaba : 1.4501307e-14
# cns : 1.290878e-14
# non-neural : 1.27037044e-14
# palate : 1.4458857e-14
# cleft : 1.4802871e-14
# non-cns : 1.263874e-14
# ectodermal : 1.4635491e-14
# vibrissae : 1.4276186e-14
# tailbud : 1.30861305e-14
# pharyngeal : 1.4754782e-14
# endoderm : 1.4081071e-14
# mesenchyme : 1.3861177e-14
# embryonic : 1.4328237e-14
# embryos : 1.466539e-14
# ectoderm : 1.4917492e-14
# buds : 1.5298684e-14
# aer : 1.492415e-14
# forelimb : 1.475571e-14
# proximal : 1.4188939e-14
# placodes : 1.4175332e-14
# mrna : 1.3229051e-14
# proteins : 1.3583359e-14
# e-e : 1.3299054e-14
# nucleotide : 1.5688478e-14
# formamide : 1.4278746e-14
# ssc : 1.5898285e-14
# gml : 1.3716842e-14
# underweight : 5.6506972e-09
# fibroblasts : 1.4062631e-14
# ipf : 1.3262123e-14
# vitro : 1.3145069e-14
# cytokines : 1.6060582e-14
# collagen : 1.3857556e-14
# fibroblast : 1.3105889e-14
# fibrotic : 1.4660075e-14
# pge : 1.1713341e-14
# txa : 1.3920287e-14
# pgi : 1.4853468e-14
# cox- : 1.3897101e-14
# hf-ipf : 1.5616736e-14
# hf-nl : 1.3553157e-14
# incubated : 1.4346995e-14
# serum : 5.0691954e-13
# dmem : 1.39686406e-14
# txb : 1.4240072e-14
# pgf : 1.5516944e-14
# il- : 1.36013e-14
# incubation : 1.4994482e-14
# trimethylsilyl : 1.4306227e-14
# buffer : 1.3149432e-14
# gel : 1.4717399e-14
# membrane : 1.2597056e-14
# tgf : 1.4613343e-14
# vascular : 4.989835e-16
# cardiac : 1.5044701e-14
# hydrolyze : 1.3612978e-14
# divalent : 1.526164e-14
# cations : 1.454172e-14
# e-ntpdase : 1.3913227e-14
# ntpdases : 1.447282e-14
# acr : 1.4994997e-14
# residues : 1.5782418e-14
# phosphate : 1.4743472e-14
# vanadyl : 1.566862e-14
# cofactor : 1.4113525e-14
# equatorial : 1.41412794e-14
# tensors : 1.4906115e-14
# epr : 1.41904e-14
# vo : 1.3266726e-14
# soluble : 1.5729166e-14
# atp : 1.35599065e-14
# adp : 1.5086714e-14
# purified : 1.3827852e-14
# nucleotidase : 1.4714507e-14
# scd : 1.3904179e-14
# adpnp : 1.3065181e-14
# spectra : 1.4082761e-14
# mhz : 1.5197589e-14
# carboxyl : 1.5074173e-14
# oxygens : 1.4567676e-14
# hydroxyl : 1.4089721e-14
# hydrolysis : 1.4591118e-14
# phosphates : 1.536486e-14
# conformations : 1.4613399e-14
# conformation : 1.3528389e-14
# annan : 1.4627119e-14
# unesco : 1.3770238e-14
# sci : 1.3795055e-14
# ricyt : 1.4501253e-14
# averaged : 5.898587e-14
# ecological : 1.4461947e-14
# statins : 1.4468127e-14
# coronary : 1.2429085e-14
# myocardial : 1.3684047e-14
# infarction : 1.445908e-14
# revascularization : 1.4107253e-14
# lipid-lowering : 1.5685664e-14
# incremental : 1.3963658e-14
# ischemia : 1.4152422e-14
# miracl : 1.5107215e-14
# atorvastatin : 1.3983247e-14
# mgdl : 1.5000347e-14
# rehospitalization : 1.4568426e-14
# worsening : 1.3476932e-14
# endpoints : 1.4479225e-14
# lipid : 1.5310505e-14
# lipoprotein : 1.3669021e-14
# ldl : 1.4424482e-14
# statin : 1.3786479e-14
# a--z : 1.3740854e-14
# simvastatin : 1.41338094e-14
# bmi : 3.172116e-07
# covariates : 2.8345116e-06
# yhl : 2.2330524e-07
# yol : 9.993034e-11
# obesity : 1.3501666e-09
# evgfp : 6.1830376e-09
# unintended : 4.678521e-09
# sizes : 2.5699336e-07
# obese : 1.9368228e-07
# <???> : 2.9195577e-05
# Prediction: some of them looks like et
